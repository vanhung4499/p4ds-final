# %% [markdown]
# # Module 1 - Thu thập dữ liệu từ [batdongsan.com.vn](https://batdongsan.com.vn/cho-thue-can-ho-chung-cu)

# %% [markdown]
# ## 1. Mục tiêu

# %% [markdown]
# ### 1.1. Kịch bản
#
# Thực hiện thu thập dữ liệu chung cư cho thuê ở thành phố Hồ Chí Minh từ [nhatot.vn](https://www.nhatot.com/thue-can-ho-chung-cu-tp-ho-chi-minh), xem xét sơ bộ ta thấy:
#
# + Mỗi trang sẽ chứa 20 tin rao cho thuê, và có khoảng 1000 trang
# + Thông tin cần phải thu thập cho mỗi căn hộ:
#
# | Columns            | Description               |
# |--------------------|---------------------------|
# | ad_id              | id của tin (để phân biệt) |
# | list_id            | id trong danh sách        |
# | subject            | Tiêu đề của tin           |
# | price              | Giá thuê                  |
# | size               | Diện tích                 |
# | rooms              | Số phòng                  |
# | toilets            | Số nhà vệ sinh            |
# | area_name          | Quận huyện                |
# | region_name        | Thành phố, tỉnh           |
# | ward_name          | Phường                    |
# | street_name        | Đuờng                     |
# | detail_address     | Địa chỉ chi tiết          |
# | zero_deposit       | Có cần tiền cọc không?    |
# | escrow_can_deposit | Cọc bao nhiêu tháng       |
# | longitude          | longitude                 |
# | latitude           | latitude                  |

# %% [markdown]
# ## 2. Thực hiện

# %% [markdown]
# ### 2.1. Import thư viện cần thiết

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait

import csv
import time
import json

# %% [markdown]
# ### 2.2. CONSTANT

# %%
SLEEP_TIME = 2
BASE_URL='https://www.nhatot.com/thue-can-ho-chung-cu-tp-ho-chi-minh'
LIMIT_PAGE = 1000

# %% [markdown]
# ### 2.3. Init chrome driver

# %%
# Các option cho chrome: ẩn danh, cửa sổ
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82 Safari/537.36"

options = webdriver.ChromeOptions()
# options.headless = True
options.add_argument(f'user-agent={user_agent}')
options.add_argument("--window-size=1920,1080")
options.add_argument('--ignore-certificate-errors')
options.add_argument('--allow-running-insecure-content')
options.add_argument("--disable-extensions")
options.add_argument("--proxy-server='direct://'")
options.add_argument("--proxy-bypass-list=*")
options.add_argument("--start-maximized")

options.add_argument('--disable-gpu')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--no-sandbox')

# khởi tạo driver
driver = webdriver.Chrome(chrome_options=options, executable_path='./driver/chromedriver')
# Out:
# /var/folders/cf/tjy8lz4n39q0hzxh7gb0n9tr0000gn/T/ipykernel_24206/2849229068.py:20: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=options, executable_path='./driver/chromedriver')

# %% [markdown]
# ### 2.3. Craw data
#
# Cách thực hiện:
#     + Do mỗi trang có sẵn một script tag với id '__NEXT_DATA__' chứa thông tin chi tiết của 20 căn hộ trong danh sách, nên ta chỉ cần request tới trang danh sách và lấy dữ liệu mà không cần vào chi trang chi tiết
#     + Vì trang web sử dụng CloudFlare security nên với chỉ mở một browser duy nhất, mỗi lần crawl xong dữ liệu cần tìm next button để chuyển qua trang tiếp theo

# %%
# get all apartments from 1000 pages
def get_data_per_page(limit):
    all_apartments = []
    page = 1
    # Go to page
    driver.get(BASE_URL)
    time.sleep(SLEEP_TIME)
    # Scroll to end of page (for finding next button)
    driver.execute_script("window.scrollBy(0,document.body.scrollHeight)","")
    time.sleep(SLEEP_TIME)

    while page <= limit:
        print(f'Get data from page {page}')
        # get raw data from a script tag
        page_source = BeautifulSoup(driver.page_source, "html.parser")
        raw_data = page_source.find('script', id='__NEXT_DATA__').string
        # convert raw to dict
        data = json.loads(raw_data)
        # get list apartment
        list_apartment = data['props']['initialState']['adlisting']['data']['ads']
        # add to results
        all_apartments.extend(list_apartment)
        # find next button need to wait page load fully
        back_next_buttons = driver.find_elements_by_class_name("Paging_redirectPageBtn__KvsqJ")
        while len(back_next_buttons) < 2:
            time.sleep(SLEEP_TIME)
            back_next_buttons = driver.find_elements_by_class_name("Paging_redirectPageBtn__KvsqJ")

        next_button = back_next_buttons[1]
        # navigate to next page
        driver.execute_script("arguments[0].click();", next_button)
        page += 1
        time.sleep(SLEEP_TIME)

    driver.close()
    driver.quit()
    return all_apartments

# %%
apartments = get_data_per_page(LIMIT_PAGE)
apartments
# Out:
# Get data from page 1
# Get data from page 2
# Get data from page 3
# Get data from page 4
# Get data from page 5
# Get data from page 6
# Get data from page 7
# Get data from page 8
# Get data from page 9
# Get data from page 10
# Get data from page 11
# Get data from page 12
# Get data from page 13
# Get data from page 14
# Get data from page 15
# Get data from page 16
# Get data from page 17
# Get data from page 18
# Get data from page 19
# Get data from page 20
# Get data from page 21
# Get data from page 22
# Get data from page 23
# Get data from page 24
# Get data from page 25
# Get data from page 26
# Get data from page 27
# Get data from page 28
# Get data from page 29
# Get data from page 30
# Get data from page 31
# Get data from page 32
# Get data from page 33
# Get data from page 34
# Get data from page 35
# Get data from page 36
# Get data from page 37
# Get data from page 38
# Get data from page 39
# Get data from page 40
# Get data from page 41
# Get data from page 42
# Get data from page 43
# Get data from page 44
# Get data from page 45
# Get data from page 46
# Get data from page 47
# Get data from page 48
# Get data from page 49
# Get data from page 50
# Get data from page 51
# Get data from page 52
# Get data from page 53
# Get data from page 54
# Get data from page 55
# Get data from page 56
# Get data from page 57
# Get data from page 58
# Get data from page 59
# Get data from page 60
# Get data from page 61
# Get data from page 62
# Get data from page 63
# Get data from page 64
# Get data from page 65
# Get data from page 66
# Get data from page 67
# Get data from page 68
# Get data from page 69
# Get data from page 70
# Get data from page 71
# Get data from page 72
# Get data from page 73
# Get data from page 74
# Get data from page 75
# Get data from page 76
# Get data from page 77
# Get data from page 78
# Get data from page 79
# Get data from page 80
# Get data from page 81
# Get data from page 82
# Get data from page 83
# Get data from page 84
# Get data from page 85
# Get data from page 86
# Get data from page 87
# Get data from page 88
# Get data from page 89
# Get data from page 90
# Get data from page 91
# Get data from page 92
# Get data from page 93
# Get data from page 94
# Get data from page 95
# Get data from page 96
# Get data from page 97
# Get data from page 98
# Get data from page 99
# Get data from page 100
# Get data from page 101
# Get data from page 102
# Get data from page 103
# Get data from page 104
# Get data from page 105
# Get data from page 106
# Get data from page 107
# Get data from page 108
# Get data from page 109
# Get data from page 110
# Get data from page 111
# Get data from page 112
# Get data from page 113
# Get data from page 114
# Get data from page 115
# Get data from page 116
# Get data from page 117
# Get data from page 118
# Get data from page 119
# Get data from page 120
# Get data from page 121
# Get data from page 122
# Get data from page 123
# Get data from page 124
# Get data from page 125
# Get data from page 126
# Get data from page 127
# Get data from page 128
# Get data from page 129
# Get data from page 130
# Get data from page 131
# Get data from page 132
# Get data from page 133
# Get data from page 134
# Get data from page 135
# Get data from page 136
# Get data from page 137
# Get data from page 138
# Get data from page 139
# Get data from page 140
# Get data from page 141
# Get data from page 142
# Get data from page 143
# Get data from page 144
# Get data from page 145
# Get data from page 146
# Get data from page 147
# Get data from page 148
# Get data from page 149
# Get data from page 150
# Get data from page 151
# Get data from page 152
# Get data from page 153
# Get data from page 154
# Get data from page 155
# Get data from page 156
# Get data from page 157
# Get data from page 158
# Get data from page 159
# Get data from page 160
# Get data from page 161
# Get data from page 162
# Get data from page 163
# Get data from page 164
# Get data from page 165
# Get data from page 166
# Get data from page 167
# Get data from page 168
# Get data from page 169
# Get data from page 170
# Get data from page 171
# Get data from page 172
# Get data from page 173
# Get data from page 174
# Get data from page 175
# Get data from page 176
# Get data from page 177
# Get data from page 178
# Get data from page 179
# Get data from page 180
# Get data from page 181
# Get data from page 182
# Get data from page 183
# Get data from page 184
# Get data from page 185
# Get data from page 186
# Get data from page 187
# Get data from page 188
# Get data from page 189
# Get data from page 190
# Get data from page 191
# Get data from page 192
# Get data from page 193
# Get data from page 194
# Get data from page 195
# Get data from page 196
# Get data from page 197
# Get data from page 198
# Get data from page 199
# Get data from page 200
# Get data from page 201
# Get data from page 202
# Get data from page 203
# Get data from page 204
# Get data from page 205
# Get data from page 206
# Get data from page 207
# Get data from page 208
# Get data from page 209
# Get data from page 210
# Get data from page 211
# Get data from page 212
# Get data from page 213
# Get data from page 214
# Get data from page 215
# Get data from page 216
# Get data from page 217
# Get data from page 218
# Get data from page 219
# Get data from page 220
# Get data from page 221
# Get data from page 222
# Get data from page 223
# Get data from page 224
# Get data from page 225
# Get data from page 226
# Get data from page 227
# Get data from page 228
# Get data from page 229
# Get data from page 230
# Get data from page 231
# Get data from page 232
# Get data from page 233
# Get data from page 234
# Get data from page 235
# Get data from page 236
# Get data from page 237
# Get data from page 238
# Get data from page 239
# Get data from page 240
# Get data from page 241
# Get data from page 242
# Get data from page 243
# Get data from page 244
# Get data from page 245
# Get data from page 246
# Get data from page 247
# Get data from page 248
# Get data from page 249
# Get data from page 250
# Get data from page 251
# Get data from page 252
# Get data from page 253
# Get data from page 254
# Get data from page 255
# Get data from page 256
# Get data from page 257
# Get data from page 258
# Get data from page 259
# Get data from page 260
# Get data from page 261
# Get data from page 262
# Get data from page 263
# Get data from page 264
# Get data from page 265
# Get data from page 266
# Get data from page 267
# Get data from page 268
# Get data from page 269
# Get data from page 270
# Get data from page 271
# Get data from page 272
# Get data from page 273
# Get data from page 274
# Get data from page 275
# Get data from page 276
# Get data from page 277
# Get data from page 278
# Get data from page 279
# Get data from page 280
# Get data from page 281
# Get data from page 282
# Get data from page 283
# Get data from page 284
# Get data from page 285
# Get data from page 286
# Get data from page 287
# Get data from page 288
# Get data from page 289
# Get data from page 290
# Get data from page 291
# Get data from page 292
# Get data from page 293
# Get data from page 294
# Get data from page 295
# Get data from page 296
# Get data from page 297
# Get data from page 298
# Get data from page 299
# Get data from page 300
# Get data from page 301
# Get data from page 302
# Get data from page 303
# Get data from page 304
# Get data from page 305
# Get data from page 306
# Get data from page 307
# Get data from page 308
# Get data from page 309
# Get data from page 310
# Get data from page 311
# Get data from page 312
# Get data from page 313
# Get data from page 314
# Get data from page 315
# Get data from page 316
# Get data from page 317
# Get data from page 318
# Get data from page 319
# Get data from page 320
# Get data from page 321
# Get data from page 322
# Get data from page 323
# Get data from page 324
# Get data from page 325
# Get data from page 326
# Get data from page 327
# Get data from page 328
# Get data from page 329
# Get data from page 330
# Get data from page 331
# Get data from page 332
# Get data from page 333
# Get data from page 334
# Get data from page 335
# Get data from page 336
# Get data from page 337
# Get data from page 338
# Get data from page 339
# Get data from page 340
# Get data from page 341
# Get data from page 342
# Get data from page 343
# Get data from page 344
# Get data from page 345
# Get data from page 346
# Get data from page 347
# Get data from page 348
# Get data from page 349
# Get data from page 350
# Get data from page 351
# Get data from page 352
# Get data from page 353
# Get data from page 354
# Get data from page 355
# Get data from page 356
# Get data from page 357
# Get data from page 358
# Get data from page 359
# Get data from page 360
# Get data from page 361
# Get data from page 362
# Get data from page 363
# Get data from page 364
# Get data from page 365
# Get data from page 366
# Get data from page 367
# Get data from page 368
# Get data from page 369
# Get data from page 370
# Get data from page 371
# Get data from page 372
# Get data from page 373
# Get data from page 374
# Get data from page 375
# Get data from page 376
# Get data from page 377
# Get data from page 378
# Get data from page 379
# Get data from page 380
# Get data from page 381
# Get data from page 382
# Get data from page 383
# Get data from page 384
# Get data from page 385
# Get data from page 386
# Get data from page 387
# Get data from page 388
# Get data from page 389
# Get data from page 390
# Get data from page 391
# Get data from page 392
# Get data from page 393
# Get data from page 394
# Get data from page 395
# Get data from page 396
# Get data from page 397
# Get data from page 398
# Get data from page 399
# Get data from page 400
# Get data from page 401
# Get data from page 402
# Get data from page 403
# Get data from page 404
# Get data from page 405
# Get data from page 406
# Get data from page 407
# Get data from page 408
# Get data from page 409
# Get data from page 410
# Get data from page 411
# Get data from page 412
# Get data from page 413
# Get data from page 414
# Get data from page 415
# Get data from page 416
# Get data from page 417
# Get data from page 418
# Get data from page 419
# Get data from page 420
# Get data from page 421
# Get data from page 422
# Get data from page 423
# Get data from page 424
# Get data from page 425
# Get data from page 426
# Get data from page 427
# Get data from page 428
# Get data from page 429
# Get data from page 430
# Get data from page 431
# Get data from page 432
# Get data from page 433
# Get data from page 434
# Get data from page 435
# Get data from page 436
# Get data from page 437
# Get data from page 438
# Get data from page 439
# Get data from page 440
# Get data from page 441
# Get data from page 442
# Get data from page 443
# Get data from page 444
# Get data from page 445
# Get data from page 446
# Get data from page 447
# Get data from page 448
# Get data from page 449
# Get data from page 450
# Get data from page 451
# Get data from page 452
# Get data from page 453
# Get data from page 454
# Get data from page 455
# Get data from page 456
# Get data from page 457
# Get data from page 458
# Get data from page 459
# Get data from page 460
# Get data from page 461
# Get data from page 462
# Get data from page 463
# Get data from page 464
# Get data from page 465
# Get data from page 466
# Get data from page 467
# Get data from page 468
# Get data from page 469
# Get data from page 470
# Get data from page 471
# Get data from page 472
# Get data from page 473
# Get data from page 474
# Get data from page 475
# Get data from page 476
# Get data from page 477
# Get data from page 478
# Get data from page 479
# Get data from page 480
# Get data from page 481
# Get data from page 482
# Get data from page 483
# Get data from page 484
# Get data from page 485
# Get data from page 486
# Get data from page 487
# Get data from page 488
# Get data from page 489
# Get data from page 490
# Get data from page 491
# Get data from page 492
# Get data from page 493
# Get data from page 494
# Get data from page 495
# Get data from page 496
# Get data from page 497
# Get data from page 498
# Get data from page 499
# Get data from page 500
# Get data from page 501
# Get data from page 502
# Get data from page 503
# Get data from page 504
# Get data from page 505
# Get data from page 506
# Get data from page 507
# Get data from page 508
# Get data from page 509
# Get data from page 510
# Get data from page 511
# Get data from page 512
# Get data from page 513
# Get data from page 514
# Get data from page 515
# Get data from page 516
# Get data from page 517
# Get data from page 518
# Get data from page 519
# Get data from page 520
# Get data from page 521
# Get data from page 522
# Get data from page 523
# Get data from page 524
# Get data from page 525
# Get data from page 526
# Get data from page 527
# Get data from page 528
# Get data from page 529
# Get data from page 530
# Get data from page 531
# Get data from page 532
# Get data from page 533
# Get data from page 534
# Get data from page 535
# Get data from page 536
# Get data from page 537
# Get data from page 538
# Get data from page 539
# Get data from page 540
# Get data from page 541
# Get data from page 542
# Get data from page 543
# Get data from page 544
# Get data from page 545
# Get data from page 546
# Get data from page 547
# Get data from page 548
# Get data from page 549
# Get data from page 550
# Get data from page 551
# Get data from page 552
# Get data from page 553
# Get data from page 554
# Get data from page 555
# Get data from page 556
# Get data from page 557
# Get data from page 558
# Get data from page 559
# Get data from page 560
# Get data from page 561
# Get data from page 562
# Get data from page 563
# Get data from page 564
# Get data from page 565
# Get data from page 566
# Get data from page 567
# Get data from page 568
# Get data from page 569
# Get data from page 570
# Get data from page 571
# Get data from page 572
# Get data from page 573
# Get data from page 574
# Get data from page 575
# Get data from page 576
# Get data from page 577
# Get data from page 578
# Get data from page 579
# Get data from page 580
# Get data from page 581
# Get data from page 582
# Get data from page 583
# Get data from page 584
# Get data from page 585
# Get data from page 586
# Get data from page 587
# Get data from page 588
# Get data from page 589
# Get data from page 590
# Get data from page 591
# Get data from page 592
# Get data from page 593
# Get data from page 594
# Get data from page 595
# Get data from page 596
# Get data from page 597
# Get data from page 598
# Get data from page 599
# Get data from page 600
# Get data from page 601
# Get data from page 602
# Get data from page 603
# Get data from page 604
# Get data from page 605
# Get data from page 606
# Get data from page 607
# Get data from page 608
# Get data from page 609
# Get data from page 610
# Get data from page 611
# Get data from page 612
# Get data from page 613
# Get data from page 614
# Get data from page 615
# Get data from page 616
# Get data from page 617
# Get data from page 618
# Get data from page 619
# Get data from page 620
# Get data from page 621
# Get data from page 622
# Get data from page 623
# Get data from page 624
# Get data from page 625
# Get data from page 626
# Get data from page 627
# Get data from page 628
# Get data from page 629
# Get data from page 630
# Get data from page 631
# Get data from page 632
# Get data from page 633
# Get data from page 634
# Get data from page 635
# Get data from page 636
# Get data from page 637
# Get data from page 638
# Get data from page 639
# Get data from page 640
# Get data from page 641
# Get data from page 642
# Get data from page 643
# Get data from page 644
# Get data from page 645
# Get data from page 646
# Get data from page 647
# Get data from page 648
# Get data from page 649
# Get data from page 650
# Get data from page 651
# Get data from page 652
# Get data from page 653
# Get data from page 654
# Get data from page 655
# Get data from page 656
# Get data from page 657
# Get data from page 658
# Get data from page 659
# Get data from page 660
# Get data from page 661
# Get data from page 662
# Get data from page 663
# Get data from page 664
# Get data from page 665
# Get data from page 666
# Get data from page 667
# Get data from page 668
# Get data from page 669
# Get data from page 670
# Get data from page 671
# Get data from page 672
# Get data from page 673
# Get data from page 674
# Get data from page 675
# Get data from page 676
# Get data from page 677
# Get data from page 678
# Get data from page 679
# Get data from page 680
# Get data from page 681
# Get data from page 682
# Get data from page 683
# Get data from page 684
# Get data from page 685
# Get data from page 686
# Get data from page 687
# Get data from page 688
# Get data from page 689
# Get data from page 690
# Get data from page 691
# Get data from page 692
# Get data from page 693
# Get data from page 694
# Get data from page 695
# Get data from page 696
# Get data from page 697
# Get data from page 698
# Get data from page 699
# Get data from page 700
# Get data from page 701
# Get data from page 702
# Get data from page 703
# Get data from page 704
# Get data from page 705
# Get data from page 706
# Get data from page 707
# Get data from page 708
# Get data from page 709
# Get data from page 710
# Get data from page 711
# Get data from page 712
# Get data from page 713
# Get data from page 714
# Get data from page 715
# Get data from page 716
# Get data from page 717
# Get data from page 718
# Get data from page 719
# Get data from page 720
# Get data from page 721
# Get data from page 722
# Get data from page 723
# Get data from page 724
# Get data from page 725
# Get data from page 726
# Get data from page 727
# Get data from page 728
# Get data from page 729
# Get data from page 730
# Get data from page 731
# Get data from page 732
# Get data from page 733
# Get data from page 734
# Get data from page 735
# Get data from page 736
# Get data from page 737
# Get data from page 738
# Get data from page 739
# Get data from page 740
# Get data from page 741
# Get data from page 742
# Get data from page 743
# Get data from page 744
# Get data from page 745
# Get data from page 746
# Get data from page 747
# Get data from page 748
# Get data from page 749
# Get data from page 750
# Get data from page 751
# Get data from page 752
# Get data from page 753
# Get data from page 754
# Get data from page 755
# Get data from page 756
# Get data from page 757
# Get data from page 758
# Get data from page 759
# Get data from page 760
# Get data from page 761
# Get data from page 762
# Get data from page 763
# Get data from page 764
# Get data from page 765
# Get data from page 766
# Get data from page 767
# Get data from page 768
# Get data from page 769
# Get data from page 770
# Get data from page 771
# Get data from page 772
# Get data from page 773
# Get data from page 774
# Get data from page 775
# Get data from page 776
# Get data from page 777
# Get data from page 778
# Get data from page 779
# Get data from page 780
# Get data from page 781
# Get data from page 782
# Get data from page 783
# Get data from page 784
# Get data from page 785
# Get data from page 786
# Get data from page 787
# Get data from page 788
# Get data from page 789
# Get data from page 790
# Get data from page 791
# Get data from page 792
# Get data from page 793
# Get data from page 794
# Get data from page 795
# Get data from page 796
# Get data from page 797
# Get data from page 798
# Get data from page 799
# Get data from page 800
# Get data from page 801
# Get data from page 802
# Get data from page 803
# Get data from page 804
# Get data from page 805
# Get data from page 806
# Get data from page 807
# Get data from page 808
# Get data from page 809
# Get data from page 810
# Get data from page 811
# Get data from page 812
# Get data from page 813
# Get data from page 814
# Get data from page 815
# Get data from page 816
# Get data from page 817
# Get data from page 818
# Get data from page 819
# Get data from page 820
# Get data from page 821
# Get data from page 822
# Get data from page 823
# Get data from page 824
# Get data from page 825
# Get data from page 826
# Get data from page 827
# Get data from page 828
# Get data from page 829
# Get data from page 830
# Get data from page 831
# Get data from page 832
# Get data from page 833
# Get data from page 834
# Get data from page 835
# Get data from page 836
# Get data from page 837
# Get data from page 838
# Get data from page 839
# Get data from page 840
# Get data from page 841
# Get data from page 842
# Get data from page 843
# Get data from page 844
# Get data from page 845
# Get data from page 846
# Get data from page 847
# Get data from page 848
# Get data from page 849
# Get data from page 850
# Get data from page 851
# Get data from page 852
# Get data from page 853
# Get data from page 854
# Get data from page 855
# Get data from page 856
# Get data from page 857
# Get data from page 858
# Get data from page 859
# Get data from page 860
# Get data from page 861
# Get data from page 862
# Get data from page 863
# Get data from page 864
# Get data from page 865
# Get data from page 866
# Get data from page 867
# Get data from page 868
# Get data from page 869
# Get data from page 870
# Get data from page 871
# Get data from page 872
# Get data from page 873
# Get data from page 874
# Get data from page 875
# Get data from page 876
# Get data from page 877
# Get data from page 878
# Get data from page 879
# Get data from page 880
# Get data from page 881
# Get data from page 882
# Get data from page 883
# Get data from page 884
# Get data from page 885
# Get data from page 886
# Get data from page 887
# Get data from page 888
# Get data from page 889
# Get data from page 890
# Get data from page 891
# Get data from page 892
# Get data from page 893
# Get data from page 894
# Get data from page 895
# Get data from page 896
# Get data from page 897
# Get data from page 898
# Get data from page 899
# Get data from page 900
# Get data from page 901
# Get data from page 902
# Get data from page 903
# Get data from page 904
# Get data from page 905
# Get data from page 906
# Get data from page 907
# Get data from page 908
# Get data from page 909
# Get data from page 910
# Get data from page 911
# Get data from page 912
# Get data from page 913
# Get data from page 914
# Get data from page 915
# Get data from page 916
# Get data from page 917
# Get data from page 918
# Get data from page 919
# Get data from page 920
# Get data from page 921
# Get data from page 922
# Get data from page 923
# Get data from page 924
# Get data from page 925
# Get data from page 926
# Get data from page 927
# Get data from page 928
# Get data from page 929
# Get data from page 930
# Get data from page 931
# Get data from page 932
# Get data from page 933
# Get data from page 934
# Get data from page 935
# Get data from page 936
# Get data from page 937
# Get data from page 938
# Get data from page 939
# Get data from page 940
# Get data from page 941
# Get data from page 942
# Get data from page 943
# Get data from page 944
# Get data from page 945
# Get data from page 946
# Get data from page 947
# Get data from page 948
# Get data from page 949
# Get data from page 950
# Get data from page 951
# Get data from page 952
# Get data from page 953
# Get data from page 954
# Get data from page 955
# Get data from page 956
# Get data from page 957
# Get data from page 958
# Get data from page 959
# Get data from page 960
# Get data from page 961
# Get data from page 962
# Get data from page 963
# Get data from page 964
# Get data from page 965
# Get data from page 966
# Get data from page 967
# Get data from page 968
# Get data from page 969
# Get data from page 970
# Get data from page 971
# Get data from page 972
# Get data from page 973
# Get data from page 974
# Get data from page 975
# Get data from page 976
# Get data from page 977
# Get data from page 978
# Get data from page 979
# Get data from page 980
# Get data from page 981
# Get data from page 982
# Get data from page 983
# Get data from page 984
# Get data from page 985
# Get data from page 986
# Get data from page 987
# Get data from page 988
# Get data from page 989
# Get data from page 990
# Get data from page 991
# Get data from page 992
# Get data from page 993
# Get data from page 994
# Get data from page 995
# Get data from page 996
# Get data from page 997
# Get data from page 998
# Get data from page 999
# Get data from page 1000
# [{'ad_id': 140064645,
#   'list_id': 101581228,
#   'list_time': None,
#   'date': '2 phút trước',
#   'account_id': 12094115,
#   'projectid': 1661,
#   'project_oid': '131318744',
#   'account_oid': None,
#   'account_name': 'Thanh Trúc',
#   'subject': 'Căn hộ cho thuê giá 7.5 triệu Khang Gia Gò Vấp',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 110,
#   'area_name': 'Quận Gò Vấp',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 7500000,
#   'price_string': '7,5 triệu/tháng',
#   'image': 'https://cdn.chotot.com/RlTA6SsqvLx1jAbFc557n-rLNRa5-u4mpppK6nmx8bM/preset:listing/plain/c0581baa7215295682e71cb3ff93f8f1-2801431311530665892.jpg',
#   'webp_image': 'https://cdn.chotot.com/2BwsaqxuliHbpITj2PGMUzN3ocz4UZH7yDcxSqZEuj8/preset:listing/plain/c0581baa7215295682e71cb3ff93f8f1-2801431311530665892.webp',
#   'videos': [],
#   'number_of_images': 9,
#   'avatar': 'https://cdn.chotot.com/uac2/12094115',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 76,
#   'region_v2': 13000,
#   'area_v2': 13110,
#   'ward': 9269,
#   'ward_name': 'Phường 14',
#   'toilets': 2,
#   'deposit': 14000000,
#   'contain_videos': 2,
#   'location': '10.8431,106.63781',
#   'longitude': 106.63781,
#   'latitude': 10.8431,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '76 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Đường Số 45, Phường 14, Gò Vấp, Hồ Chí Minh',
#   'street_name': 'Số 45',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 1},
#  {'ad_id': 139204943,
#   'list_id': 100868150,
#   'list_time': None,
#   'date': '3 phút trước',
#   'account_id': 22395751,
#   'projectid': 1,
#   'project_oid': '987630212',
#   'account_oid': None,
#   'account_name': 'Phương Tâm',
#   'subject': 'CHO THUÊ 13TR FULL NT 2PN-THE SUN AVENUE Q2',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 119,
#   'area_name': 'Thành phố Thủ Đức',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 13000000,
#   'price_string': '13 triệu/tháng',
#   'image': 'https://cdn.chotot.com/BaOSGoxfHuP5YasG1Di5fm-NGrvHCr88yyOfxBNzSkc/preset:listing/plain/a7a86be6ece3c06c204d766cd0f0205c-2801466587589988183.jpg',
#   'webp_image': 'https://cdn.chotot.com/sz6tdqvLSNEM_x9JxR2Tkzb3CZmNIfjfaFcKVpZMso4/preset:listing/plain/a7a86be6ece3c06c204d766cd0f0205c-2801466587589988183.webp',
#   'videos': [],
#   'number_of_images': 3,
#   'avatar': 'https://cdn.chotot.com/uac2/22395751',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 56,
#   'region_v2': 13000,
#   'area_v2': 13119,
#   'ward': 9341,
#   'ward_name': 'Phường An Phú (Quận 2 cũ)',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.80719,106.75142',
#   'longitude': 106.75142,
#   'latitude': 10.80719,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': '28',
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '56 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Đường An Phú',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 2},
#  {'ad_id': 139614436,
#   'list_id': 101207971,
#   'list_time': None,
#   'date': '3 phút trước',
#   'account_id': 23258140,
#   'projectid': 22,
#   'project_oid': '1860214211',
#   'account_oid': None,
#   'account_name': 'Minh Tân',
#   'subject': 'Cho Thuê Căn Hộ 3PN DREAMHOME PALACE NT như hình',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 103,
#   'area_name': 'Quận 8',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 8000000,
#   'price_string': '8 triệu/tháng',
#   'image': 'https://cdn.chotot.com/ctwZijhivPk5_pD4w58h13unKD3axloeQuNv7zRT53g/preset:listing/plain/393e2546852214d7e239b491e6c74a2a-2799705038601612986.jpg',
#   'webp_image': 'https://cdn.chotot.com/haxORnSBlYEJZvJSZbQQijz-VdW46qpRVTWj32VlnGk/preset:listing/plain/393e2546852214d7e239b491e6c74a2a-2799705038601612986.webp',
#   'videos': [],
#   'number_of_images': 8,
#   'avatar': 'https://cdn.chotot.com/uac2/23258140',
#   'rooms': 3,
#   'apartment_type': 1,
#   'size': 79,
#   'region_v2': 13000,
#   'area_v2': 13103,
#   'ward': 9455,
#   'ward_name': 'Phường 7',
#   'toilets': 2,
#   'contain_videos': 2,
#   'location': '10.70677,106.62474',
#   'longitude': 106.62474,
#   'latitude': 10.70677,
#   'phone_hidden': True,
#   'address': 'Đường Trịnh Quan Nghị, Phường 7, Quận 8, Thành phố Hồ Chí Minh',
#   'owner': False,
#   'street_id': 32171,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '79 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '3 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 3},
#  {'ad_id': 140081070,
#   'list_id': 101595037,
#   'list_time': None,
#   'date': '4 phút trước',
#   'account_id': 16973519,
#   'account_oid': None,
#   'account_name': 'MEGAS Ivy Nguyen',
#   'subject': '🔥 NOEL ĐẶC BIỆT🔥 CĂN HỘ CHO THUÊ GIÁ RẺ QUẬN 10',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 105,
#   'area_name': 'Quận 10',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 6200000,
#   'price_string': '6,2 triệu/tháng',
#   'image': 'https://cdn.chotot.com/Z0Jlw1gvYTEGsFz_3QeTicK-NsKwwLxiEumI4J7MSjA/preset:listing/plain/c4e75d01b7bc652e252ccd71b994ea49-2801466272790794018.jpg',
#   'webp_image': 'https://cdn.chotot.com/ClIxo6uHZ3crVBfUZgIGcaw6GNXFd7GzzEDWk-5CBgY/preset:listing/plain/c4e75d01b7bc652e252ccd71b994ea49-2801466272790794018.webp',
#   'videos': [],
#   'number_of_images': 9,
#   'avatar': 'https://cdn.chotot.com/uac2/16973519',
#   'rooms': 1,
#   'apartment_type': 1,
#   'size': 30,
#   'region_v2': 13000,
#   'area_v2': 13105,
#   'ward': 9367,
#   'ward_name': 'Phường 14',
#   'toilets': 1,
#   'deposit': 6200000,
#   'contain_videos': 2,
#   'location': '10.77188,106.66371',
#   'longitude': 106.66371,
#   'latitude': 10.77188,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '30 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Hẻm 51 Thành Thái',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 4},
#  {'ad_id': 134246472,
#   'list_id': 96807427,
#   'list_time': None,
#   'date': '5 phút trước',
#   'account_id': 4068857,
#   'projectid': 1515,
#   'project_oid': '1387857486',
#   'account_oid': None,
#   'account_name': 'Đại Phong',
#   'subject': 'Căn hộ Hưng Ngân 2PN, 70m2, full nội thất, ở liền',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 107,
#   'area_name': 'Quận 12',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 7500000,
#   'price_string': '7,5 triệu/tháng',
#   'image': 'https://cdn.chotot.com/u-ji-DUV4yAzw1KydHLdcNMy6i9S8-qErFN1QgUXEUo/preset:listing/plain/e23737796c5b491e06b48b19b8903537-2801156116185278718.jpg',
#   'webp_image': 'https://cdn.chotot.com/uD_FO9MIyyAkfI8ekmQOkOThLO8QSgneNOzGnMUx29U/preset:listing/plain/e23737796c5b491e06b48b19b8903537-2801156116185278718.webp',
#   'videos': [],
#   'number_of_images': 12,
#   'avatar': 'https://cdn.chotot.com/uac2/4068857',
#   'rooms': 2,
#   'property_legal_document': 1,
#   'apartment_type': 1,
#   'size': 68,
#   'region_v2': 13000,
#   'area_v2': 13107,
#   'ward': 9231,
#   'ward_name': 'Phường Tân Chánh Hiệp',
#   'direction': 3,
#   'block': 'B',
#   'floornumber': 15,
#   'toilets': 2,
#   'balconydirection': 4,
#   'unitnumber': 'B',
#   'deposit': 15000000,
#   'apartment_feature': 1,
#   'contain_videos': 2,
#   'location': '10.8683,106.62596',
#   'longitude': 106.62596,
#   'latitude': 10.8683,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '68 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Quận 12, Tp Hồ Chí Minh',
#   'street_name': 'Đường Tân Chánh Hiệp 21, Phường Tân Chánh Hiệp, Quận 12, Hồ Chí Minh',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 5},
#  {'ad_id': 117438110,
#   'list_id': 83322659,
#   'list_time': None,
#   'date': '5 phút trước',
#   'account_id': 16865141,
#   'account_oid': None,
#   'account_name': 'Nguyễn Xuân Thái',
#   'subject': 'Cănhộ gác cao full nội thất q7 hướng về trung tâm',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 102,
#   'area_name': 'Quận 7',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 5000000,
#   'price_string': '5 triệu/tháng',
#   'image': 'https://cdn.chotot.com/MSpciQaofIKECgEsRJUMDlQc5uGCyitDSvuTHAxdLHw/preset:listing/plain/b84573072da982bcb2143dfc47d8f6e1-2797303093231141643.jpg',
#   'webp_image': 'https://cdn.chotot.com/T2sE66furiMpmT9fqzDcuIUVKX9VaWNgr1lVup0sI94/preset:listing/plain/b84573072da982bcb2143dfc47d8f6e1-2797303093231141643.webp',
#   'videos': [],
#   'number_of_images': 12,
#   'avatar': 'https://cdn.chotot.com/uac2/16865141',
#   'rooms': 1,
#   'apartment_type': 1,
#   'size': 35,
#   'region_v2': 13000,
#   'area_v2': 13102,
#   'ward': 9471,
#   'ward_name': 'Phường Tân Quy',
#   'toilets': 1,
#   'unitnumber_display': 1,
#   'deposit': 5000000,
#   'contain_videos': 2,
#   'location': '10.73864,106.71178',
#   'longitude': 106.71178,
#   'latitude': 10.73864,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '35 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Đường Nguyễn Thị Thập',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 6},
#  {'ad_id': 140081025,
#   'list_id': 101595011,
#   'list_time': None,
#   'date': '5 phút trước',
#   'account_id': 11261327,
#   'projectid': 1449,
#   'project_oid': '192900716',
#   'account_oid': None,
#   'account_name': 'Trâm',
#   'subject': 'NTCB chỉ 26 triệu, 2pn, Empire City, Thủ Thiêm Q2',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 119,
#   'area_name': 'Thành phố Thủ Đức',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 27500000,
#   'price_string': '27,5 triệu/tháng',
#   'image': 'https://cdn.chotot.com/kHawr_S086D9eohnHo1dD2LLYc6J1P9YQ_S4xAkQ40A/preset:listing/plain/916bad841a2e3c1b3c7be2c4105b5bdf-2801463454551713700.jpg',
#   'webp_image': 'https://cdn.chotot.com/PaK3y2wWnXHiT9LF41wR0mZXcHSiXbkhY_zBT4PIlg4/preset:listing/plain/916bad841a2e3c1b3c7be2c4105b5bdf-2801463454551713700.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/nQeofhJm28Kb6cUGurXTDGze0VeCxK2jm9lEjP-FS_o/preset:view/plain/7acc808a9496acbcff60d8a2f8dadfbd-2801463454458620782.jpg',
#    'https://cdn.chotot.com/FIWbTSjcJUX3ptjztcjjJhcVeQzlDpsySgCDMqc0kZg/preset:view/plain/f4eb7b8e66ad517a4e8e44616e412051-2801463454574616225.jpg',
#    'https://cdn.chotot.com/9-nn7sXqepvtkAUtibnheXTRfeZh0UwEjQ_9iFlUJp4/preset:view/plain/cb90ced21fbfbfc3e512f4088da007b6-2801463454861702727.jpg',
#    'https://cdn.chotot.com/b_PfM6YqAB2dM95Gw1ID2E4K5sJnV4j2t-L_6qNlRi4/preset:view/plain/80cef760ebd2e79259792591e3e33fea-2801463454807576407.jpg',
#    'https://cdn.chotot.com/5N-i98ubaJm7CSSYc1-zE7F4F4VMEiuNSIQAVBF-GPE/preset:view/plain/e517ba4899c6469ce25569750281240d-2801463454836016717.jpg'],
#   'special_display': True,
#   'number_of_images': 8,
#   'avatar': 'https://cdn.chotot.com/uac2/11261327',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 95,
#   'region_v2': 13000,
#   'area_v2': 13119,
#   'ward': 9350,
#   'ward_name': 'Phường Thủ Thiêm (Quận 2 cũ)',
#   'toilets': 2,
#   'contain_videos': 2,
#   'location': '10.77166,106.7173',
#   'longitude': 106.7173,
#   'latitude': 10.77166,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '95 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Đường Mai Chí Thọ, phường Thủ Thiêm, quận 2, Tp.HCM',
#   'street_name': 'Mai Chí Thọ',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 7},
#  {'ad_id': 140081020,
#   'list_id': 101595010,
#   'list_time': None,
#   'date': '6 phút trước',
#   'account_id': 26756,
#   'projectid': 3479,
#   'project_oid': '824127826',
#   'account_oid': None,
#   'account_name': 'Diễm phương',
#   'subject': 'CHO THUÊ CH Q7 RIVERSIDE 53m2, 1PN FULL MỚI 100%',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 102,
#   'area_name': 'Quận 7',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 10000000,
#   'price_string': '10 triệu/tháng',
#   'image': 'https://cdn.chotot.com/tlUhTTwFy_B4qXqqN4qJUXnq_7W4ZIEDydHYbzbEf8E/preset:property_project_small/plain/3479_sample_house_8.jpg',
#   'videos': [],
#   'avatar': 'https://cdn.chotot.com/uac2/26756',
#   'rooms': 1,
#   'apartment_type': 1,
#   'projectimages': '3479_sample_house_8,3479_facilities_6,3479_facilities_5',
#   'size': 53,
#   'region_v2': 13000,
#   'area_v2': 13102,
#   'ward': 9472,
#   'ward_name': 'Phường Phú Thuận',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.722,106.7433',
#   'longitude': 106.7433,
#   'latitude': 10.722,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': 'Số 4',
#   'protection_entitlement': True,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '53 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Số 4 Đường Đào Trí',
#   'street_name': 'Đào Trí',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 8},
#  {'ad_id': 115608611,
#   'list_id': 81876366,
#   'list_time': None,
#   'date': '6 phút trước',
#   'account_id': 5177801,
#   'account_oid': None,
#   'account_name': 'Thai Van Tan',
#   'subject': 'Căn Hộ Mini Phú Hoàng Anh Nguyễn Hữu Thọ',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 118,
#   'area_name': 'Huyện Nhà Bè',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 5500000,
#   'price_string': '5,5 triệu/tháng',
#   'image': 'https://cdn.chotot.com/QHrR1l1yqL12V1ntg5g9Sdw9-A0QGTXe36DTNIEQuwk/preset:listing/plain/d8fe1fb73e1b087db03b080594e31818-2796932606259586459.jpg',
#   'webp_image': 'https://cdn.chotot.com/p3dsyU9ysWC19gwrENRqdd72e7UjJEfLU5t0Lh4-Iz4/preset:listing/plain/d8fe1fb73e1b087db03b080594e31818-2796932606259586459.webp',
#   'videos': [{'id': '5398421264ff41878c2e336de418830f',
#     'thumbnail': 'https://videodelivery.net/5398421264ff41878c2e336de418830f/thumbnails/thumbnail.jpg',
#     'url': 'https://videodelivery.net/5398421264ff41878c2e336de418830f/manifest/video.m3u8'}],
#   'has_video': True,
#   'number_of_images': 8,
#   'avatar': 'https://cdn.chotot.com/uac2/5177801',
#   'rooms': 1,
#   'property_legal_document': 1,
#   'apartment_type': 1,
#   'size': 30,
#   'region_v2': 13000,
#   'area_v2': 13118,
#   'ward': 9526,
#   'ward_name': 'Xã Phước Kiển',
#   'direction': 6,
#   'block': 'D',
#   'floornumber': 26,
#   'toilets': 1,
#   'balconydirection': 8,
#   'unitnumber': '3',
#   'unitnumber_display': 1,
#   'deposit': 6500000,
#   'apartment_feature': 1,
#   'contain_videos': 1,
#   'location': '10.70387,106.71276',
#   'longitude': 106.71276,
#   'latitude': 10.70387,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': 'D',
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '30 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Nguyễn Hữu Thọ',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 9},
#  {'ad_id': 139702517,
#   'list_id': 101281478,
#   'list_time': None,
#   'date': '7 phút trước',
#   'account_id': 23682325,
#   'account_oid': None,
#   'account_name': 'Nguyen Phu',
#   'subject': '🔥🔥Hệ thống CH 2 Phòng Ngủ. Ngã tư PHÚ NHUẬN🎪🎪',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 111,
#   'area_name': 'Quận Phú Nhuận',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 9300000,
#   'price_string': '9,3 triệu/tháng',
#   'image': 'https://cdn.chotot.com/ZXyfgZyBPd7osWJdFXBfNOwfyH6dbM9cy234F3m0ERo/preset:listing/plain/19c65aa44d8db93fa0e13fc7d4e861d6-2800052909195778234.jpg',
#   'webp_image': 'https://cdn.chotot.com/Kn6Mjt9YoVNTVZBGo4QcWLt0ZZ1mEoMy6oMLfLgTsGU/preset:listing/plain/19c65aa44d8db93fa0e13fc7d4e861d6-2800052909195778234.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/lIoD-qW9jeqkDS5oA8aZMTsaIuRPxC41Oz-aSTMVYYc/preset:view/plain/e0c9be96b1a0cbcf67941fd6d221139e-2800052909075274889.jpg',
#    'https://cdn.chotot.com/EtcKz_SiPMPrvPcZA8JCQZc8qyoYv1Q34tsap87yylE/preset:view/plain/a0c1e8b6113a53a6a8d84c2029d6f137-2800052955168058590.jpg',
#    'https://cdn.chotot.com/l51qJVhjKOxmHjBlSyjsK2lZ2LSuVXjEvQMvE2O4-wg/preset:view/plain/79e23d6f7847b853667a983202bdb28e-2800052955162728699.jpg',
#    'https://cdn.chotot.com/MZWB5CvPNlP1tfiiT4TGONFC248Nkm9wFJWjSmDyPQQ/preset:view/plain/6245ed5466f966092872132edc93ee68-2800052995945987452.jpg',
#    'https://cdn.chotot.com/Iyb4_F3ZKzs_-ty3XBtAd9n3Z5S7PJLHbu_7fVEnsHQ/preset:view/plain/32c59598535c3f36f41ee69b69054b58-2800052995948534011.jpg'],
#   'special_display': True,
#   'number_of_images': 12,
#   'avatar': 'https://cdn.chotot.com/uac2/23682325',
#   'rooms': 2,
#   'apartment_type': 2,
#   'size': 70,
#   'region_v2': 13000,
#   'area_v2': 13111,
#   'ward': 9336,
#   'ward_name': 'Phường 17',
#   'toilets': 2,
#   'deposit': 9300000,
#   'contain_videos': 2,
#   'location': '10.79605,106.67476',
#   'longitude': 106.67476,
#   'latitude': 10.79605,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': True,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '70 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Đường Nguyễn Văn Trỗi',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 10},
#  {'ad_id': 140080953,
#   'list_id': 101594958,
#   'list_time': None,
#   'date': '8 phút trước',
#   'account_id': 22775019,
#   'account_oid': None,
#   'account_name': 'Hoài Nhi Hifriendz hình thật giá chất',
#   'subject': 'Duplex ban công full nội thất ngay KCX -hỗ trợ cọc',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 102,
#   'area_name': 'Quận 7',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 5800000,
#   'price_string': '5,8 triệu/tháng',
#   'image': 'https://cdn.chotot.com/uDubagr7KVGvC8hPgJAS_ykClrj0lqJWrOXTpMZsyoY/preset:listing/plain/77fd7081510c5dde9a394d4c3b7ef0c0-2801468452983595298.jpg',
#   'webp_image': 'https://cdn.chotot.com/utPliYrNACTI1j8hM5W0rO7B4EOpNTHOJojejuzbF4E/preset:listing/plain/77fd7081510c5dde9a394d4c3b7ef0c0-2801468452983595298.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/ThGYjr1LVi-h8Ga4MP82x3rukc_zpHRk_UvcOeY1PEE/preset:view/plain/c4f633aa4c6c6f2217ef5cc6b4581a13-2801468453032209460.jpg',
#    'https://cdn.chotot.com/WEI6hEIa6bszceiP159Y5GbQa6-sG6DwEGOynaCbRHQ/preset:view/plain/6c83c7ef4e12c6ccc0b7398d7b81d49b-2801468454560719138.jpg',
#    'https://cdn.chotot.com/6Wu2Y1Low9_Uey1ske029zSS_5vXqCe9ig4G6qxQhpE/preset:view/plain/8290bccb5d6e64793513f5185679ad6f-2801468454792684721.jpg',
#    'https://cdn.chotot.com/vfOwnipbhFbTlORsKN0iftTyG1yt9NNwAtD1jWF5gWs/preset:view/plain/054a91b74cf00725c87d271a146f1f74-2801468456319476913.jpg'],
#   'special_display': True,
#   'number_of_images': 5,
#   'avatar': 'https://cdn.chotot.com/uac2/22775019',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 35,
#   'region_v2': 13000,
#   'area_v2': 13102,
#   'ward': 9470,
#   'ward_name': 'Phường Bình Thuận',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.74129,106.7287',
#   'longitude': 106.7287,
#   'latitude': 10.74129,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '35 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Huỳnh Tấn Phát',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 11},
#  {'ad_id': 140080931,
#   'list_id': 101594950,
#   'list_time': None,
#   'date': '8 phút trước',
#   'account_id': 14177950,
#   'account_oid': None,
#   'account_name': 'Hùng',
#   'subject': 'Căn hộ mới 100% đầy đủ nội thất',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 105,
#   'area_name': 'Quận 10',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 5000000,
#   'price_string': '5 triệu/tháng',
#   'image': 'https://cdn.chotot.com/WMUqkEv1sE3TKIBDcPjCP_XjlAg5Zf7v237pjuo14sY/preset:listing/plain/0d4ccd8e0794493b20cd18abcf5ad0c9-2801468287649291937.jpg',
#   'webp_image': 'https://cdn.chotot.com/c6C5DvzlEdX6QkYV72iNAqKr4RYqCFY0LUoqZW8mjDM/preset:listing/plain/0d4ccd8e0794493b20cd18abcf5ad0c9-2801468287649291937.webp',
#   'videos': [],
#   'number_of_images': 3,
#   'avatar': 'https://cdn.chotot.com/uac2/14177950',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 25,
#   'region_v2': 13000,
#   'area_v2': 13105,
#   'ward': 9368,
#   'ward_name': 'Phường 12',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.78131,106.67672',
#   'longitude': 106.67672,
#   'latitude': 10.78131,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '25 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Đường Cách Mạng Tháng Tám',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 12},
#  {'ad_id': 139994138,
#   'list_id': 101523043,
#   'list_time': None,
#   'date': '9 phút trước',
#   'account_id': 9079758,
#   'projectid': 3658,
#   'project_oid': '1247214303',
#   'account_oid': None,
#   'account_name': 'Thương Thương',
#   'subject': 'Kingdom - cho thuê 2pn2wc full nội thất 20triệu',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 105,
#   'area_name': 'Quận 10',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 20000000,
#   'price_string': '20 triệu/tháng',
#   'image': 'https://cdn.chotot.com/YrJSjkf90OhlMFvJupULIU-ESv0UNwgMQ-ESdLUY0kQ/preset:listing/plain/7dfceb9ce156461b772cc98ec85b4f5c-2801164959897801334.jpg',
#   'webp_image': 'https://cdn.chotot.com/iiOIMi_PnGz2uADTvckertSh3CufB-ghOF1DnO5WFpA/preset:listing/plain/7dfceb9ce156461b772cc98ec85b4f5c-2801164959897801334.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/FZ8nfJaS7v-2bLPsD3dQe3cJ-RWpOWUEODBrRZcvm4w/preset:view/plain/b61e1277a6e6ad4688b843dba4ee3102-2801164959906503114.jpg',
#    'https://cdn.chotot.com/TvvoAyUcux5DmLwD0R832-HqHSbMz4DObbc3U3VPhBk/preset:view/plain/06c4774af43c45e653a47f4f10623271-2801164959903843481.jpg',
#    'https://cdn.chotot.com/KPgO2uGJcGJSn_9esxUtnSHqRWMUPaVrw13Eh2AcPXY/preset:view/plain/fb391f9cd9b34e3e79f823326da615a1-2801164959899605745.jpg',
#    'https://cdn.chotot.com/cD534R1fJeAD7HOD_NlNFqtreZcQO7is00CzCqiaM94/preset:view/plain/1ea7aa159197573e9dfdc41d06d35740-2801164959897709976.jpg',
#    'https://cdn.chotot.com/R4ZdFjDxnjyJghE9rFmafyC6p90iDNfq7jYAWSymASI/preset:view/plain/c5f8d905fca73ff67fd525bb6ce77655-2801164959767639428.jpg'],
#   'special_display': True,
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/9079758',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 72.5,
#   'region_v2': 13000,
#   'area_v2': 13105,
#   'ward': 9367,
#   'ward_name': 'Phường 14',
#   'toilets': 2,
#   'contain_videos': 2,
#   'location': '10.7747,106.66218',
#   'longitude': 106.66218,
#   'latitude': 10.7747,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': '334',
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '72.5 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Tô Hiến Thành',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 13},
#  {'ad_id': 140080873,
#   'list_id': 101594911,
#   'list_time': None,
#   'date': '10 phút trước',
#   'account_id': 2413149,
#   'account_oid': None,
#   'account_name': 'Tobi',
#   'subject': 'Căn hộ full nội thất gần công viên Gia Định',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 111,
#   'area_name': 'Quận Phú Nhuận',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 4500000,
#   'price_string': '4,5 triệu/tháng',
#   'image': 'https://cdn.chotot.com/iWyC4Z6spCtsFIGkwhivWmT-qc7GNjkqAusTixFenWs/preset:listing/plain/532e0bc9b4ea2f52cdcdbcf1d6b01be1-2801467839839942215.jpg',
#   'webp_image': 'https://cdn.chotot.com/PtNqeVg3M-mVlue5T0QbPdw8ejmgB_TOL_OKdh-bWFQ/preset:listing/plain/532e0bc9b4ea2f52cdcdbcf1d6b01be1-2801467839839942215.webp',
#   'videos': [],
# ...
#   'area_v2': 13102,
#   'ward': 9470,
#   'ward_name': 'Phường Bình Thuận',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.74129,106.7287',
#   'longitude': 106.7287,
#   'latitude': 10.74129,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '35 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Huỳnh Tấn Phát',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 11},
#  {'ad_id': 140080931,
#   'list_id': 101594950,
#   'list_time': None,
#   'date': '8 phút trước',
#   'account_id': 14177950,
#   'account_oid': None,
#   'account_name': 'Hùng',
#   'subject': 'Căn hộ mới 100% đầy đủ nội thất',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 105,
#   'area_name': 'Quận 10',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 5000000,
#   'price_string': '5 triệu/tháng',
#   'image': 'https://cdn.chotot.com/WMUqkEv1sE3TKIBDcPjCP_XjlAg5Zf7v237pjuo14sY/preset:listing/plain/0d4ccd8e0794493b20cd18abcf5ad0c9-2801468287649291937.jpg',
#   'webp_image': 'https://cdn.chotot.com/c6C5DvzlEdX6QkYV72iNAqKr4RYqCFY0LUoqZW8mjDM/preset:listing/plain/0d4ccd8e0794493b20cd18abcf5ad0c9-2801468287649291937.webp',
#   'videos': [],
#   'number_of_images': 3,
#   'avatar': 'https://cdn.chotot.com/uac2/14177950',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 25,
#   'region_v2': 13000,
#   'area_v2': 13105,
#   'ward': 9368,
#   'ward_name': 'Phường 12',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.78131,106.67672',
#   'longitude': 106.67672,
#   'latitude': 10.78131,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '25 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Đường Cách Mạng Tháng Tám',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 12},
#  {'ad_id': 139994138,
#   'list_id': 101523043,
#   'list_time': None,
#   'date': '9 phút trước',
#   'account_id': 9079758,
#   'projectid': 3658,
#   'project_oid': '1247214303',
#   'account_oid': None,
#   'account_name': 'Thương Thương',
#   'subject': 'Kingdom - cho thuê 2pn2wc full nội thất 20triệu',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 105,
#   'area_name': 'Quận 10',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 20000000,
#   'price_string': '20 triệu/tháng',
#   'image': 'https://cdn.chotot.com/YrJSjkf90OhlMFvJupULIU-ESv0UNwgMQ-ESdLUY0kQ/preset:listing/plain/7dfceb9ce156461b772cc98ec85b4f5c-2801164959897801334.jpg',
#   'webp_image': 'https://cdn.chotot.com/iiOIMi_PnGz2uADTvckertSh3CufB-ghOF1DnO5WFpA/preset:listing/plain/7dfceb9ce156461b772cc98ec85b4f5c-2801164959897801334.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/FZ8nfJaS7v-2bLPsD3dQe3cJ-RWpOWUEODBrRZcvm4w/preset:view/plain/b61e1277a6e6ad4688b843dba4ee3102-2801164959906503114.jpg',
#    'https://cdn.chotot.com/TvvoAyUcux5DmLwD0R832-HqHSbMz4DObbc3U3VPhBk/preset:view/plain/06c4774af43c45e653a47f4f10623271-2801164959903843481.jpg',
#    'https://cdn.chotot.com/KPgO2uGJcGJSn_9esxUtnSHqRWMUPaVrw13Eh2AcPXY/preset:view/plain/fb391f9cd9b34e3e79f823326da615a1-2801164959899605745.jpg',
#    'https://cdn.chotot.com/cD534R1fJeAD7HOD_NlNFqtreZcQO7is00CzCqiaM94/preset:view/plain/1ea7aa159197573e9dfdc41d06d35740-2801164959897709976.jpg',
#    'https://cdn.chotot.com/R4ZdFjDxnjyJghE9rFmafyC6p90iDNfq7jYAWSymASI/preset:view/plain/c5f8d905fca73ff67fd525bb6ce77655-2801164959767639428.jpg'],
#   'special_display': True,
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/9079758',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 72.5,
#   'region_v2': 13000,
#   'area_v2': 13105,
#   'ward': 9367,
#   'ward_name': 'Phường 14',
#   'toilets': 2,
#   'contain_videos': 2,
#   'location': '10.7747,106.66218',
#   'longitude': 106.66218,
#   'latitude': 10.7747,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': '334',
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '72.5 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Tô Hiến Thành',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 13},
#  {'ad_id': 140080873,
#   'list_id': 101594911,
#   'list_time': None,
#   'date': '10 phút trước',
#   'account_id': 2413149,
#   'account_oid': None,
#   'account_name': 'Tobi',
#   'subject': 'Căn hộ full nội thất gần công viên Gia Định',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 111,
#   'area_name': 'Quận Phú Nhuận',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 4500000,
#   'price_string': '4,5 triệu/tháng',
#   'image': 'https://cdn.chotot.com/iWyC4Z6spCtsFIGkwhivWmT-qc7GNjkqAusTixFenWs/preset:listing/plain/532e0bc9b4ea2f52cdcdbcf1d6b01be1-2801467839839942215.jpg',
#   'webp_image': 'https://cdn.chotot.com/PtNqeVg3M-mVlue5T0QbPdw8ejmgB_TOL_OKdh-bWFQ/preset:listing/plain/532e0bc9b4ea2f52cdcdbcf1d6b01be1-2801467839839942215.webp',
#   'videos': [],
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/2413149',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 30,
#   'region_v2': 13000,
#   'area_v2': 13111,
#   'ward': 9327,
#   'ward_name': 'Phường 9',
#   'toilets': 1,
#   'deposit': 4500000,
#   'contain_videos': 2,
#   'location': '10.808407,106.67364',
#   'longitude': 106.67364,
#   'latitude': 10.808407,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '30 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Lê Lợi',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 14},
#  {'ad_id': 128955229,
#   'list_id': 92424900,
#   'list_time': None,
#   'date': '10 phút trước',
#   'account_id': 10713797,
#   'projectid': 383,
#   'project_oid': '1148357882',
#   'account_oid': None,
#   'account_name': 'Ngô Bá Tuyên',
#   'subject': 'Chung cư The Sun Avenue 105m² 3 PN',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 119,
#   'area_name': 'Thành phố Thủ Đức',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 16000000,
#   'price_string': '16 triệu/tháng',
#   'image': 'https://cdn.chotot.com/84QC63n8mstLq_51M7ClKUM9r-NF3osAncSNyDRMdYM/preset:listing/plain/090c3f02c1700f3d9164c840c145fd84-2761170360405548686.jpg',
#   'webp_image': 'https://cdn.chotot.com/2kqImlVdqrBojgR3jdvCiQY5JsKfT1AoXdLSekDlH7w/preset:listing/plain/090c3f02c1700f3d9164c840c145fd84-2761170360405548686.webp',
#   'videos': [],
#   'number_of_images': 5,
#   'avatar': 'https://cdn.chotot.com/uac2/10713797',
#   'rooms': 3,
#   'apartment_type': 1,
#   'size': 105,
#   'region_v2': 13000,
#   'area_v2': 13119,
#   'ward': 9341,
#   'ward_name': 'Phường An Phú (Quận 2 cũ)',
#   'toilets': 2,
#   'unitnumber_display': 1,
#   'furnishing_rent': 2,
#   'contain_videos': 2,
#   'location': '10.80634,106.75525',
#   'longitude': 106.75525,
#   'latitude': 10.80634,
#   'phone_hidden': True,
#   'address': 'Đường Mai Chí Thọ, Phường An Phú, Quận 2, Hồ Chí Minh',
#   'owner': False,
#   'street_id': 3141,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '105 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '3 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 15},
#  {'ad_id': 139857116,
#   'list_id': 101410137,
#   'list_time': None,
#   'date': '10 phút trước',
#   'account_id': 11182055,
#   'account_oid': None,
#   'account_name': 'Thanh Nguyên',
#   'subject': 'Căn hộ mini full nội thất 1PN AEON Tân Phú',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 108,
#   'area_name': 'Quận Bình Tân',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 4200000,
#   'price_string': '4,2 triệu/tháng',
#   'image': 'https://cdn.chotot.com/9nbryWKGjukSP-HS-PUMH_A-wwCCblPcN_i58t2lo1Y/preset:listing/plain/8dd37730875b397e5204eb9fa9e26585-2801422571338126854.jpg',
#   'webp_image': 'https://cdn.chotot.com/fgLpVhRa5NOUVyZ7hR8_vtexdVU1dl9D-e1L0KVigTg/preset:listing/plain/8dd37730875b397e5204eb9fa9e26585-2801422571338126854.webp',
#   'videos': [],
#   'number_of_images': 4,
#   'avatar': 'https://cdn.chotot.com/uac2/11182055',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 25,
#   'region_v2': 13000,
#   'area_v2': 13108,
#   'ward': 9456,
#   'ward_name': 'Phường Bình Hưng Hòa',
#   'toilets': 1,
#   'deposit': 4200000,
#   'contain_videos': 2,
#   'location': '10.80625,106.60365',
#   'longitude': 106.60365,
#   'latitude': 10.80625,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': '277',
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '25 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Đường Số 5',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 16},
#  {'ad_id': 140080174,
#   'list_id': 101594865,
#   'list_time': None,
#   'date': '12 phút trước',
#   'account_id': 14776690,
#   'projectid': 383,
#   'project_oid': '1148357882',
#   'account_oid': None,
#   'account_name': 'Tien Nguyen',
#   'subject': 'Cho thue căn hộ 2PN The Sun Avenue, dọn vào ở ngay',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 119,
#   'area_name': 'Thành phố Thủ Đức',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 17000000,
#   'price_string': '17 triệu/tháng',
#   'image': 'https://cdn.chotot.com/HMM_hrdgoy72iPQ6wANJs5iwSiNX-WfAQxMAvvNELX0/preset:listing/plain/d2425c6afcc7b6504d1c1a8ed57a4d8d-2801465797013591558.jpg',
#   'webp_image': 'https://cdn.chotot.com/V_ELdCnAkVFa131gJEK25KCEd7j8Q70tfgrkM2ORLac/preset:listing/plain/d2425c6afcc7b6504d1c1a8ed57a4d8d-2801465797013591558.webp',
#   'videos': [],
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/14776690',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 75,
#   'region_v2': 13000,
#   'area_v2': 13119,
#   'ward': 9341,
#   'ward_name': 'Phường An Phú (Quận 2 cũ)',
#   'toilets': 2,
#   'deposit': 34000000,
#   'contain_videos': 2,
#   'location': '10.79675,106.75218',
#   'longitude': 106.75218,
#   'latitude': 10.79675,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '75 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Đường Mai Chí Thọ, Phường An Phú, Quận 2, Hồ Chí Minh',
#   'street_name': 'Mai Chí Thọ',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 17},
#  {'ad_id': 140080820,
#   'list_id': 101594857,
#   'list_time': None,
#   'date': '12 phút trước',
#   'account_id': 26756,
#   'projectid': 120,
#   'project_oid': '1675720589',
#   'account_oid': None,
#   'account_name': 'Diễm phương',
#   'subject': 'CHO THUÊ CH ERA TOWN 2PN VIEW SÔNG FULL NỘI THẤT',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 102,
#   'area_name': 'Quận 7',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 8500000,
#   'price_string': '8,5 triệu/tháng',
#   'image': 'https://cdn.chotot.com/nWmhqLa5ySNbNT4lNP-7nMxCeRT1waA7T34RsUwsSUU/preset:listing/plain/0b3e7e4864a70ed8cd802156062cc11f-2801467753794756164.jpg',
#   'webp_image': 'https://cdn.chotot.com/OenCrp5d1wByCyvdCj_JvYlDhvOncl7Hsd8iCrynsL8/preset:listing/plain/0b3e7e4864a70ed8cd802156062cc11f-2801467753794756164.webp',
#   'videos': [],
#   'number_of_images': 3,
#   'avatar': 'https://cdn.chotot.com/uac2/26756',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 78,
#   'region_v2': 13000,
#   'area_v2': 13102,
#   'ward': 9475,
#   'ward_name': 'Phường Phú Mỹ',
#   'toilets': 2,
#   'balconydirection': 3,
#   'contain_videos': 2,
#   'location': '10.70316,106.73216',
#   'longitude': 106.73216,
#   'latitude': 10.70316,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': True,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '78 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Đường 15B',
#   'street_name': '15B',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 18},
#  {'ad_id': 140080802,
#   'list_id': 101594844,
#   'list_time': None,
#   'date': '12 phút trước',
#   'account_id': 13437547,
#   'projectid': 1372,
#   'project_oid': '1233201385',
#   'account_oid': None,
#   'account_name': 'Nguyễn Trường',
#   'subject': 'Cho thuê 2PN Sunwah Pearl lầu cao giá siêu tốt',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 109,
#   'area_name': 'Quận Bình Thạnh',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 29500000,
#   'price_string': '29,5 triệu/tháng',
#   'image': 'https://cdn.chotot.com/GzOC1hUlxPalA92a_e2EI7NaxeZd8jmykbMO3enXahE/preset:listing/plain/57a192464595a25f4f1f89ba7ecf22ef-2801464933628714441.jpg',
#   'webp_image': 'https://cdn.chotot.com/Jr89R5J31ZW5t-mtYokP8lKSLOkZHMqH7hC2QKJzJ30/preset:listing/plain/57a192464595a25f4f1f89ba7ecf22ef-2801464933628714441.webp',
#   'videos': [],
#   'number_of_images': 8,
#   'avatar': 'https://cdn.chotot.com/uac2/13437547',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 102,
#   'region_v2': 13000,
#   'area_v2': 13109,
#   'ward': 9296,
#   'ward_name': 'Phường 22',
#   'toilets': 2,
#   'deposit': 29500000,
#   'contain_videos': 2,
#   'location': '10.78995,106.71774',
#   'longitude': 106.71774,
#   'latitude': 10.78995,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': 'Số 90',
#   'protection_entitlement': True,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '102 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Số 90 Số 90 Nguyễn Hữu Cảnh, phường 22, quận Bình Thạnh, Tp.HCM',
#   'street_name': 'Nguyễn Hữu Cảnh',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 19},
#  {'ad_id': 140080800,
#   'list_id': 101594840,
#   'list_time': None,
#   'date': '12 phút trước',
#   'account_id': 12055354,
#   'projectid': 2483,
#   'project_oid': '480579574',
#   'account_oid': None,
#   'account_name': 'Minh Thuan Real Estate',
#   'subject': 'Thuê ngay Căn hộ 3PN view trực diện sông',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 119,
#   'area_name': 'Thành phố Thủ Đức',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 49000000,
#   'price_string': '49 triệu/tháng',
#   'image': 'https://cdn.chotot.com/3VYslUmhAJyTRIwgZTYMM08LfybI0e-vgwJ8b9fQihE/preset:listing/plain/37f7bcdd3013c6e4599650e88783fc68-2801467567684261769.jpg',
#   'webp_image': 'https://cdn.chotot.com/WtbGUp___WLAQN3i0CFC4PUTie7UUkMl6Bkyd4fqssU/preset:listing/plain/37f7bcdd3013c6e4599650e88783fc68-2801467567684261769.webp',
#   'videos': [],
#   'number_of_images': 9,
#   'avatar': 'https://cdn.chotot.com/uac2/12055354',
#   'rooms': 3,
#   'property_legal_document': 1,
#   'apartment_type': 1,
#   'size': 128,
#   'region_v2': 13000,
#   'area_v2': 13119,
#   'ward': 9340,
#   'ward_name': 'Phường Thảo Điền (Quận 2 cũ)',
#   'block': 'T2',
#   'floornumber': 16,
#   'toilets': 3,
#   'contain_videos': 2,
#   'location': '10.80513,106.74682',
#   'longitude': 106.74682,
#   'latitude': 10.80513,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '128 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '3 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'đường Võ Trường Toản',
#   'street_name': 'Võ Trường Toản',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 20},
#  ...]

# %% [markdown]
# ## 2.4. Filter data

# %%
need_keys = ['ad_id', 'list_id', 'subject', 'price', 'size', 'rooms', 'toilets', 'area_name', 'region_name', 'ward_name', 'street_name', 'detail_address', 'escrow_can_deposit', 'zero_deposit', 'longitude', 'latitude']

def filer_apartment(apartment):
    return { key: apartment[key] if key in apartment else '' for key in need_keys }

new_apartments = list(map(filer_apartment, apartments))
new_apartments[0]
# Out:
# {'ad_id': 140064645,
#  'list_id': 101581228,
#  'subject': 'Căn hộ cho thuê giá 7.5 triệu Khang Gia Gò Vấp',
#  'price': 7500000,
#  'size': 76,
#  'rooms': 2,
#  'toilets': 2,
#  'area_name': 'Quận Gò Vấp',
#  'region_name': 'Tp Hồ Chí Minh',
#  'ward_name': 'Phường 14',
#  'street_name': 'Số 45',
#  'detail_address': 'Đường Số 45, Phường 14, Gò Vấp, Hồ Chí Minh',
#  'escrow_can_deposit': 2,
#  'zero_deposit': False,
#  'longitude': 106.63781,
#  'latitude': 10.8431}

# %% [markdown]
# ### 2.5. Write to csv

# %%
list_apartment = [[apartment[key] for key in need_keys] for apartment in new_apartments]

with open('./data/hcm-apartment-rent-data.csv', 'w') as f:
    write = csv.writer(f)
    write.writerow(need_keys)
    write.writerows(list_apartment)
