# %% [markdown]
# # Module 1 - Thu thập dữ liệu từ [nhatot.vn](https://www.nhatot.com/thue-can-ho-chung-cu-tp-ho-chi-minh)

# %% [markdown]
# ## 1. Mục tiêu

# %% [markdown]
# ### 1.1. Kịch bản
#
# Thực hiện thu thập dữ liệu chung cư cho thuê ở thành phố Hồ Chí Minh từ [nhatot.vn](https://www.nhatot.com/thue-can-ho-chung-cu-tp-ho-chi-minh), xem xét sơ bộ ta thấy:
#
# + Mỗi trang sẽ chứa 20 tin rao cho thuê, và có khoảng 1000 trang
# + Thông tin cần phải thu thập cho mỗi căn hộ:
#
# | Column              | Description               |
# |---------------------|---------------------------|
# | ad_id               | id của tin (để phân biệt) |
# | list_id             | id trong danh sách        |
# | subject             | Tiêu đề của tin           |
# | price               | Giá thuê                  |
# | size                | Diện tích                 |
# | rooms               | Số phòng                  |
# | toilets             | Số nhà vệ sinh            |
# | area_name           | Quận huyện                |
# | region_name         | Thành phố, tỉnh           |
# | ward_name           | Phường                    |
# | street_name         | Đuờng                     |
# | detail_address      | Địa chỉ chi tiết          |
# | zero_deposit        | Có cần tiền cọc không?    |
# | escrow_can_deposit  | Cọc bao nhiêu tháng       |
# | longitude           | Kinh độ                   |
# | latitude            | Vĩ độ                     |

# %% [markdown]
# ## 2. Thực hiện

# %% [markdown]
# ### 2.1. Import thư viện cần thiết

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait

import csv
import time
import json

# %% [markdown]
# ### 2.2. CONSTANT

# %%
SLEEP_TIME = 6
BASE_URL='https://www.nhatot.com/thue-can-ho-chung-cu-tp-ho-chi-minh'
LIMIT_PAGE = 1000

# %% [markdown]
# ### 2.3. Init chrome driver

# %%
# Các option cho chrome: ẩn danh, cửa sổ
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.82 Safari/537.36"

options = webdriver.ChromeOptions()
# options.headless = True
options.add_argument(f'user-agent={user_agent}')
options.add_argument("--window-size=1920,1080")
# options.add_argument('--ignore-certificate-errors')
# options.add_argument('--allow-running-insecure-content')
# options.add_argument("--disable-extensions")
# options.add_argument("--proxy-server='direct://'")
# options.add_argument("--proxy-bypass-list=*")
# options.add_argument("--start-maximized")
#
# options.add_argument('--disable-gpu')
# options.add_argument('--disable-dev-shm-usage')
# options.add_argument('--no-sandbox')

# khởi tạo driver
driver = webdriver.Chrome(chrome_options=options, executable_path='./driver/chromedriver')
# Out:
# /var/folders/cf/tjy8lz4n39q0hzxh7gb0n9tr0000gn/T/ipykernel_25715/2067507462.py:20: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=options, executable_path='./driver/chromedriver')

# %% [markdown]
# ### 2.3. Craw data
#
# Cách thực hiện:
#     + Do mỗi trang có sẵn một script tag với id '__NEXT_DATA__' chứa thông tin chi tiết của 20 căn hộ trong danh sách, nên ta chỉ cần request tới trang danh sách và lấy dữ liệu mà không cần vào chi trang chi tiết
#     + Vì trang web sử dụng CloudFlare security nên với chỉ mở một browser duy nhất, mỗi lần crawl xong dữ liệu cần tìm next button để chuyển qua trang tiếp theo

# %%
# get all apartments from 1000 pages
def get_data_per_page(limit):
    all_apartments = []
    page = limit
    # Go to page
    last_page_url = f'{BASE_URL}?page={page}'
    driver.get(last_page_url)
    time.sleep(SLEEP_TIME)
    # Scroll to end of page (for finding next button)
    driver.execute_script("window.scrollBy(0,document.body.scrollHeight)","")
    time.sleep(SLEEP_TIME)
    old_raw = ''

    while page > 1:
        print(f'Get data from page {page}')
        # get raw data from a script tag
        page_source = BeautifulSoup(driver.page_source, "html.parser")
        new_raw = page_source.find('script', id='__NEXT_DATA__').string
        print(old_raw == new_raw)
        # convert raw to dict
        data = json.loads(new_raw)
        # get list apartment
        list_apartment = data['props']['initialState']['adlisting']['data']['ads']
        # add to results
        all_apartments.extend(list_apartment)
        # find next button need to wait page load fully
        back_next_buttons = driver.find_elements_by_class_name("Paging_redirectPageBtn__KvsqJ")
        while len(back_next_buttons) < 2:
            time.sleep(SLEEP_TIME)
            back_next_buttons = driver.find_elements_by_class_name("Paging_redirectPageBtn__KvsqJ")

        back_button = back_next_buttons[0]
        # navigate to next page
        page -= 1
        driver.execute_script("arguments[0].click();", back_button)
        time.sleep(SLEEP_TIME)
        driver.execute_script("window.scrollBy(0,document.body.scrollHeight)","")
        time.sleep(SLEEP_TIME)
        old_raw = new_raw


    driver.close()
    driver.quit()
    return all_apartments

# %%
apartments = get_data_per_page(5)
apartments
# Out:
# Get data from page 5
# False
# Get data from page 4
# True
# Get data from page 3
# True
# Get data from page 2
# True
# [{'ad_id': 137787704,
#   'list_id': 99708659,
#   'list_time': None,
#   'date': '59 phút trước',
#   'account_id': 15981029,
#   'account_oid': None,
#   'account_name': 'Nguyễn Linh APARTMENT',
#   'subject': 'Căn hộ Quận 10_An Ninh Sạch Sẽ_Gần Toà VIETTEL',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 105,
#   'area_name': 'Quận 10',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 6300000,
#   'price_string': '6,3 triệu/tháng',
#   'image': 'https://cdn.chotot.com/9QprvKV7dDSDGjy6h53oM5XQZ4t2WCX-z-k690M9Nek/preset:listing/plain/e16dcb5dfedba23056ceeb10f379f422-2801285738674522264.jpg',
#   'webp_image': 'https://cdn.chotot.com/o9675yTI2c4JhgtktOuJhD81QKITpfKPykc55nDMsZM/preset:listing/plain/e16dcb5dfedba23056ceeb10f379f422-2801285738674522264.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/hDSV00sPxCVlv1BRKhwBaqYFBTTPhZdM4Hd7XoQjtAI/preset:view/plain/aef515c31a5b37fd5e0a7d2c161e6d40-2801285740932032784.jpg',
#    'https://cdn.chotot.com/iuxdJ39kjB_juKTKLzw2e0piAzly1XfhkviUPEuRtSw/preset:view/plain/fc1fb992308e7e0e14f568c0232784dd-2801285739199303355.jpg',
#    'https://cdn.chotot.com/ykguTMTAynaP9Ohzge5w2rGTOSIZtFxp1eSxpAprZcA/preset:view/plain/98f27f0c406f05daa1a50c9192684e72-2801285738710991722.jpg',
#    'https://cdn.chotot.com/RtX3ayBlV4XhQZ6LvGFC4Cs8h8HeIwGGmHTOlZhzZ8A/preset:view/plain/b17c2f8b3a09d7ee4d456b4f63e123a2-2801285742684407960.jpg',
#    'https://cdn.chotot.com/RZJk51iYjz7XNN_N5CGqOkdCKbvPuq7CyzKnmQxhjF0/preset:view/plain/8234e0d6fb6d7292b4f7c7bff4ceacf9-2801285742369883957.jpg'],
#   'special_display': True,
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/15981029',
#   'rooms': 1,
#   'property_legal_document': 1,
#   'apartment_type': 2,
#   'size': 30,
#   'region_v2': 13000,
#   'area_v2': 13105,
#   'ward': 9368,
#   'ward_name': 'Phường 12',
#   'block': 'A',
#   'floornumber': 3,
#   'toilets': 1,
#   'unitnumber': '1',
#   'unitnumber_display': 1,
#   'deposit': 6300,
#   'apartment_feature': 1,
#   'contain_videos': 2,
#   'location': '10.77493,106.66558',
#   'longitude': 106.66558,
#   'latitude': 10.77493,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': '491',
#   'protection_entitlement': True,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '30 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Đường Cách Mạng Tháng Tám',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 1},
#  {'ad_id': 130295918,
#   'list_id': 93547414,
#   'list_time': None,
#   'date': '59 phút trước',
#   'account_id': 2782360,
#   'projectid': 1,
#   'project_oid': '987630212',
#   'account_oid': None,
#   'account_name': 'PHAN ANH HÙNG',
#   'shop_alias': 'X5zJlLgXddb2RUm',
#   'subject': 'Cho thuê căn hộ city gate 3pn giá 9 triệu',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 103,
#   'area_name': 'Quận 8',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 9000000,
#   'price_string': '9 triệu/tháng',
#   'image': 'https://cdn.chotot.com/0dRt0C1LpgtVyAseJu4ctU_80YeSf3kXuHiCaq_XalQ/preset:listing/plain/3dd6a50217a33819277e4ce612748868-2766051298123399706.jpg',
#   'webp_image': 'https://cdn.chotot.com/XKmPCb5NOb_5Izy-doMVrp2oABwmCzc9OVhKo61l9NA/preset:listing/plain/3dd6a50217a33819277e4ce612748868-2766051298123399706.webp',
#   'videos': [],
#   'number_of_images': 7,
#   'shop': {'alias': 'X5zJlLgXddb2RUm',
#    'status': 'expired',
#    'name': 'PHAN ANH HÙNG BDS',
#    'address': 'phường 12, quận 10',
#    'profileImageUrl': 'https://cdn.chotot.com/JOpXCJx99rB9XDrADv8N-wIwpsAAkEGRdO2_nj-D4zk/preset:shopava/plain/f746a5656d07d626283c3d520f674f06-2769687142369395106.jpg',
#    'createdDate': '2022-04-25T03:14:05.000Z',
#    'modifiedDate': 1653448818,
#    'urls': [{'url': 'phan-anh-hung-bds'}],
#    'shopsCategoriesRelationships': [{'categoryId': 1000}]},
#   'avatar': 'https://cdn.chotot.com/uac2/2782360',
#   'rooms': 3,
#   'apartment_type': 1,
#   'size': 92,
#   'region_v2': 13000,
#   'area_v2': 13103,
#   'ward': 9454,
#   'ward_name': 'Phường 16',
#   'toilets': 2,
#   'deposit': 18000000,
#   'contain_videos': 2,
#   'location': '10.72873,106.62398',
#   'longitude': 106.62398,
#   'latitude': 10.72873,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': '15',
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '92 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '3 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Võ Văn Kiệt, phường 16, quận 8',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 2},
#  {'ad_id': 140162255,
#   'list_id': 101662114,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 21645975,
#   'account_oid': None,
#   'account_name': 'Mạnh Hùng AC Homes',
#   'subject': 'Căn Hộ Giá Rẻ Q.Tân Phú',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 113,
#   'area_name': 'Quận Tân Phú',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 3600000,
#   'price_string': '3,6 triệu/tháng',
#   'image': 'https://cdn.chotot.com/Hsd5sOBVK85nhSxjRdMHDK05-L8-YWw37pDLwK-99_Y/preset:listing/plain/d7ce18b72d6113d54b0fc913605026af-2801775966253165796.jpg',
#   'webp_image': 'https://cdn.chotot.com/H5yY8WM2qlCc8FUfCNPwMLdZJ2BKbxSnYqX65TkPFA4/preset:listing/plain/d7ce18b72d6113d54b0fc913605026af-2801775966253165796.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/Vqhvo_dXqPSYKvBmArR-_oHHTK4TPe40BW6wvcXcmw0/preset:view/plain/b569f74069a7948d6a8605a12d6fe5ca-2801775966002677445.jpg',
#    'https://cdn.chotot.com/3Jge3nqeHGtk0zNxe35yDYJ4tLaOSBtUAHjuXl8HHME/preset:view/plain/b8696a66f6105ec64197eae892f7f0b6-2801775966261637496.jpg',
#    'https://cdn.chotot.com/6cOoohblBIvSnbxbJgGivY5ffmsBrYVJILitLojEYOg/preset:view/plain/393f2f7eeaf15b8e485ae8d108eb6502-2801775965940919683.jpg'],
#   'special_display': True,
#   'number_of_images': 4,
#   'avatar': 'https://cdn.chotot.com/uac2/21645975',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 30,
#   'region_v2': 13000,
#   'area_v2': 13113,
#   'ward': 9315,
#   'ward_name': 'Phường Tây Thạnh',
#   'toilets': 1,
#   'deposit': 3600000,
#   'contain_videos': 2,
#   'location': '10.812291,106.62618',
#   'longitude': 106.62618,
#   'latitude': 10.812291,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '30 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Tây Thạnh',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 3},
#  {'ad_id': 140110416,
#   'list_id': 101631390,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 22301822,
#   'account_oid': None,
#   'account_name': 'Thế Anh',
#   'subject': 'STUDIO ra vào tự do BC THOÁNG cửa sổ LỚN ở liền❤❤',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 109,
#   'area_name': 'Quận Bình Thạnh',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 4100000,
#   'price_string': '4,1 triệu/tháng',
#   'image': 'https://cdn.chotot.com/nZ_QOxXASKq_9I7NiP7yTkHikJuMXLcCjHlcScURHnQ/preset:listing/plain/c7ef92d2dbf50ddcc1a0e7bc9625b353-2801593067958281693.jpg',
#   'webp_image': 'https://cdn.chotot.com/73VVd9uUyiYfu9frJ0GNZ4LWJAEFFsrhsMLYyU-eslE/preset:listing/plain/c7ef92d2dbf50ddcc1a0e7bc9625b353-2801593067958281693.webp',
#   'videos': [],
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/22301822',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 23,
#   'region_v2': 13000,
#   'area_v2': 13109,
#   'ward': 9287,
#   'ward_name': 'Phường 24',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.80713,106.70785',
#   'longitude': 106.70785,
#   'latitude': 10.80713,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': True,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '23 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Hẻm 47 Bùi Đình Túy',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 4},
#  {'ad_id': 139175708,
#   'list_id': 100844215,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 17194237,
#   'projectid': 122,
#   'project_oid': '1352502191',
#   'account_oid': None,
#   'account_name': 'Nguyễn thanh Huyền',
#   'subject': 'Cho thuê giá tốt  studio The Manor, view lung linh',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 109,
#   'area_name': 'Quận Bình Thạnh',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 12000000,
#   'price_string': '12 triệu/tháng',
#   'image': 'https://cdn.chotot.com/ecqpm92PIKqErrK747M20RFZNbYfrNVpTt7ZHEnfiRI/preset:listing/plain/73e0af0cbdf2ce587f9246eae57b6875-2798143367443377965.jpg',
#   'webp_image': 'https://cdn.chotot.com/z27ocPGEoCvD1n6aIZDr5euX0jkgHtIhjilrmBtZ_xk/preset:listing/plain/73e0af0cbdf2ce587f9246eae57b6875-2798143367443377965.webp',
#   'videos': [],
#   'number_of_images': 10,
#   'avatar': 'https://cdn.chotot.com/uac2/17194237',
#   'rooms': 1,
#   'apartment_type': 1,
#   'size': 38,
#   'region_v2': 13000,
#   'area_v2': 13109,
#   'ward': 9296,
#   'ward_name': 'Phường 22',
#   'direction': 5,
#   'floornumber': 20,
#   'toilets': 1,
#   'balconydirection': 6,
#   'contain_videos': 2,
#   'location': '10.78921,106.71094',
#   'longitude': 106.71094,
#   'latitude': 10.78921,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '38 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Đường Nguyễn Hữu Cảnh',
#   'street_name': 'Nguyễn Hữu Cảnh',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 5},
#  {'ad_id': 140150035,
#   'list_id': 101651909,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 19943946,
#   'account_oid': None,
#   'account_name': 'Căn hộ MQ',
#   'subject': 'Căn hộ 1Pn ngay Etown Cộng Hoà - Full nội thất',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 112,
#   'area_name': 'Quận Tân Bình',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 8000000,
#   'price_string': '8 triệu/tháng',
#   'image': 'https://cdn.chotot.com/npb9FQOHsGnb-Itf5tHr0Yo7z-JXmcR_RQSCnpnLLnE/preset:listing/plain/9e392c6e702998a2d65ce848ab0c5000-2801740127207891451.jpg',
#   'webp_image': 'https://cdn.chotot.com/hpbvmRozN7aAQ7IfaaoEUfO1nADNWRUQWk2kx2HOtrM/preset:listing/plain/9e392c6e702998a2d65ce848ab0c5000-2801740127207891451.webp',
#   'videos': [],
#   'number_of_images': 10,
#   'avatar': 'https://cdn.chotot.com/uac2/19943946',
#   'rooms': 1,
#   'apartment_type': 1,
#   'size': 45,
#   'region_v2': 13000,
#   'area_v2': 13112,
#   'ward': 9302,
#   'ward_name': 'Phường 13',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.80309,106.64451',
#   'longitude': 106.64451,
#   'latitude': 10.80309,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '45 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Đường Cộng Hoà',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 6},
#  {'ad_id': 140031266,
#   'list_id': 101553845,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 9724860,
#   'projectid': 2710,
#   'project_oid': '1964456515',
#   'account_oid': None,
#   'account_name': 'HOÀNG THÀNH',
#   'subject': 'THUÊ NGAY CH OFFICETEL LAVITA CHARM',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 119,
#   'area_name': 'Thành phố Thủ Đức',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 5000000,
#   'price_string': '5 triệu/tháng',
#   'image': 'https://cdn.chotot.com/ypVpbp2k_sR3TP2hPnWxqn2rSyTRaNBQaNA9lk7-KLs/preset:listing/plain/73b910490e59dc3e3a7c1a85d75d53cc-2801302527751954146.jpg',
#   'webp_image': 'https://cdn.chotot.com/vBufM0aZg_CxUmSxZSVACuKIw3vmyEyRDzx9RndIfB4/preset:listing/plain/73b910490e59dc3e3a7c1a85d75d53cc-2801302527751954146.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/tIURwEhAaXjZhUDKUDnPC5_BJoq2Pfg7cOWhRbJHp2A/preset:view/plain/905ca826018979021cfcc4a776f67c53-2801302528006752408.jpg',
#    'https://cdn.chotot.com/d4kdG0NJrW0ESGjUeb4G1veUXBF-n0nHegXwof3RHu8/preset:view/plain/ea7bcd73398590fe70f96db45bd4e3ba-2801302527676299225.jpg',
#    'https://cdn.chotot.com/vhOunbgthBGwe9aJMq-SCW7-qd36a014sTtNsc9WCLE/preset:view/plain/8d688a3db4848d5add4c0b074ee1ec6b-2801302528078220615.jpg',
#    'https://cdn.chotot.com/hy-1ubjTG2nD3-KAXPWVxUhX75AWkyWS5E-FzVgovt4/preset:view/plain/f0088f0b05939422d2a07de85f8aada6-2801302527759638806.jpg',
#    'https://cdn.chotot.com/2WltHVGIJAupc2ynQYiqBF2-JVkGKWGXLXSy83xE6MQ/preset:view/plain/ce54609865521237b8b1f42e832c5b3b-2801302526899192552.jpg'],
#   'special_display': True,
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/9724860',
#   'rooms': 1,
#   'apartment_type': 1,
#   'size': 35,
#   'region_v2': 13000,
#   'area_v2': 13119,
#   'ward': 9249,
#   'ward_name': 'Phường Trường Thọ (Quận Thủ Đức cũ)',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.8267,106.75855',
#   'longitude': 106.75855,
#   'latitude': 10.8267,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': True,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '35 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Đường số 1, phường Trường Thọ, quận Thủ Đức, Tp.HCM',
#   'street_name': 'Số 1',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 7},
#  {'ad_id': 140162072,
#   'list_id': 101661971,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 11051019,
#   'account_oid': None,
#   'account_name': 'Huynh Tuan Viet',
#   'subject': 'Khai trương Duplex_Mặt tiền Hồ Văn Huê_Ngay CA PN',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 111,
#   'area_name': 'Quận Phú Nhuận',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 5500000,
#   'price_string': '5,5 triệu/tháng',
#   'image': 'https://cdn.chotot.com/oQcac8Yg-GAo59ncWvs0QCc6e9hz0Zbvo02sJAhnQKo/preset:listing/plain/1042399310770c95554442bce5a8d29f-2801775050313559579.jpg',
#   'webp_image': 'https://cdn.chotot.com/djJWHRyX18uyZcihD_oRDuQB043FDozAAxdsX9G_-eM/preset:listing/plain/1042399310770c95554442bce5a8d29f-2801775050313559579.webp',
#   'videos': [],
#   'number_of_images': 9,
#   'avatar': 'https://cdn.chotot.com/uac2/11051019',
#   'rooms': 1,
#   'apartment_type': 1,
#   'size': 25,
#   'region_v2': 13000,
#   'area_v2': 13111,
#   'ward': 9327,
#   'ward_name': 'Phường 9',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.80283,106.6767',
#   'longitude': 106.6767,
#   'latitude': 10.80283,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '25 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Đường Hồ Văn Huê',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 8},
#  {'ad_id': 139873858,
#   'list_id': 101424191,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 15808419,
#   'projectid': 4439,
#   'project_oid': '912878226',
#   'account_oid': None,
#   'account_name': 'MAI YÊN',
#   'subject': 'Q7 BOULEVARD CHO THUÊ CĂN 2PN-8TR/THÁNG',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 102,
#   'area_name': 'Quận 7',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 8000000,
#   'price_string': '8 triệu/tháng',
#   'image': 'https://cdn.chotot.com/pFyrDzbiZHkcmVaGpDDD98vN0oxhLlpWJnnWRR0V21Q/preset:listing/plain/183e984c3a77e9a06c7aa5cb7ff8c02a-2800702147331502407.jpg',
#   'webp_image': 'https://cdn.chotot.com/ilL3JERjBRz9MGQbK5erHEDtMCZolS8MHw3NZj2Nd2E/preset:listing/plain/183e984c3a77e9a06c7aa5cb7ff8c02a-2800702147331502407.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/yjjT6j-b0CGuCwvbX_7VuoxSppURWhB5GDERqA5-hZU/preset:view/plain/36e72af89a39bcc8a0cb0c7d7625f453-2800702148658086531.jpg',
#    'https://cdn.chotot.com/xouMw-eDCgJd1OzTUFZHG6w4tIxHF2mL_ufvMoJYs7A/preset:view/plain/b049b51390970f71d34284b5904f6d87-2800702171917024332.jpg',
#    'https://cdn.chotot.com/ebGOrGQsfsMVsDuS4rG9yfCm5PGyHZd3yECN_c7qKow/preset:view/plain/a3f2ac7802cadcd9cc6db2f64cbcc797-2800702173036364419.jpg',
#    'https://cdn.chotot.com/6kooNU49tV05HtcaK2eHRtuYxYMVMePyFqNOQuLQc00/preset:view/plain/a855146ee22b29a7c77208c39765dca7-2800702173079144104.jpg',
#    'https://cdn.chotot.com/Ykhn7t69quuRCOCUmQJPSfgvReejk9cwGFln_ca-mxE/preset:view/plain/6db7bd00fd83c9867d5937408767a4f1-2800702172023932190.jpg'],
#   'special_display': True,
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/15808419',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 70,
#   'region_v2': 13000,
#   'area_v2': 13102,
#   'ward': 9475,
#   'ward_name': 'Phường Phú Mỹ',
#   'toilets': 2,
#   'contain_videos': 2,
#   'location': '10.70729,106.73198',
#   'longitude': 106.73198,
#   'latitude': 10.70729,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': True,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '70 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Đường Nguyễn Lương Bằng, Phường Phú Mỹ, Quận 7, Hồ Chí Minh',
#   'street_name': 'Nguyễn Lương Bằng',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 9},
#  {'ad_id': 140125286,
#   'list_id': 101631513,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 23691397,
#   'account_oid': None,
#   'account_name': 'Hoàng Bảo',
#   'subject': '🌼Cho Thuê Căn Hộ 1PN,Bancol Sang Trọng Gần SânBay',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 112,
#   'area_name': 'Quận Tân Bình',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 8400000,
#   'price_string': '8,4 triệu/tháng',
#   'image': 'https://cdn.chotot.com/XxoQ_KYRiByaLSZXYz22zGX-Z9kFgF5CwkSICUw3CN0/preset:listing/plain/738b4ba9dce0161afc480b4422b8fb86-2801633720427498415.jpg',
#   'webp_image': 'https://cdn.chotot.com/rz7bXg0hJleuDb7ooBYAWamPzi7cc6dUZaoSfrL_ZRI/preset:listing/plain/738b4ba9dce0161afc480b4422b8fb86-2801633720427498415.webp',
#   'videos': [{'id': '3896eb476d1f41eb825e025529891ac5',
#     'thumbnail': 'https://videodelivery.net/3896eb476d1f41eb825e025529891ac5/thumbnails/thumbnail.jpg',
#     'url': 'https://videodelivery.net/3896eb476d1f41eb825e025529891ac5/manifest/video.m3u8'}],
#   'has_video': True,
#   'number_of_images': 11,
#   'avatar': 'https://cdn.chotot.com/uac2/23691397',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 35,
#   'region_v2': 13000,
#   'area_v2': 13112,
#   'ward': 9300,
#   'ward_name': 'Phường 4',
#   'toilets': 1,
#   'contain_videos': 1,
#   'location': '10.80518,106.66261',
#   'longitude': 106.66261,
#   'latitude': 10.80518,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '35 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Đường Nguyễn Cảnh Dị',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 10},
#  {'ad_id': 140161823,
#   'list_id': 101661926,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 23362281,
#   'account_oid': None,
#   'account_name': 'Trịnh Anh Hào',
#   'subject': 'Khai Trương CHDV mới 100% FULL nội thất hiện đại..',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 109,
#   'area_name': 'Quận Bình Thạnh',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 9000000,
#   'price_string': '9 triệu/tháng',
#   'image': 'https://cdn.chotot.com/2KJ3l9EPixmmL1_D67F1PqS7V7Z-s0rKA9WXj3eJ_ac/preset:listing/plain/1e8b630e5615c52471babb00e791171c-2801774441109892483.jpg',
#   'webp_image': 'https://cdn.chotot.com/KpxC-ofC4sf2pNFaQOWiqEukxVquD8ldpWi_Ehnyy5E/preset:listing/plain/1e8b630e5615c52471babb00e791171c-2801774441109892483.webp',
#   'videos': [],
#   'number_of_images': 8,
#   'avatar': 'https://cdn.chotot.com/uac2/23362281',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 35,
#   'region_v2': 13000,
#   'area_v2': 13109,
#   'ward': 9284,
#   'ward_name': 'Phường 25',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.80408,106.71333',
#   'longitude': 106.71333,
#   'latitude': 10.80408,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': True,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '35 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'điện biên phủ',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 11},
#  {'ad_id': 140144407,
#   'list_id': 101647132,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 16755595,
#   'account_oid': None,
#   'account_name': 'nguyễn minh khải',
#   'subject': 'Căn Hộ Mới 100% - Đối Diện Vinhomes - Bình Thạnh',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 109,
#   'area_name': 'Quận Bình Thạnh',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 16000000,
#   'price_string': '16 triệu/tháng',
#   'image': 'https://cdn.chotot.com/tupO7YQOfgGV7Rj59v7j0ghHvD-wT4MmsFzReYm2agQ/preset:listing/plain/5398f1ae1b80de32a6ca7877d60f57ba-2801726285926012174.jpg',
#   'webp_image': 'https://cdn.chotot.com/PgcdMO89ptmfNGS7Ed1I1NKHzH2relxdJPcCp5tBuXI/preset:listing/plain/5398f1ae1b80de32a6ca7877d60f57ba-2801726285926012174.webp',
#   'videos': [],
#   'number_of_images': 8,
#   'avatar': 'https://cdn.chotot.com/uac2/16755595',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 50,
#   'region_v2': 13000,
#   'area_v2': 13109,
#   'ward': 9296,
#   'ward_name': 'Phường 22',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.79395,106.72092',
#   'longitude': 106.72092,
#   'latitude': 10.79395,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '50 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Nguyễn Hữu Cảnh',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 12},
#  {'ad_id': 140161831,
#   'list_id': 101661890,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 23677342,
#   'account_oid': None,
#   'account_name': 'THUỲ LING HOUSE',
#   'subject': '🆘1PN 35m2 MẶT TIỀN THOÁNG MÁT GIÁ ƯU ĐÃI BTHANH',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 109,
#   'area_name': 'Quận Bình Thạnh',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 7000000,
#   'price_string': '7 triệu/tháng',
#   'image': 'https://cdn.chotot.com/dNxtMpGmtl9uKEuXxGMSTkAJUHkvZYWhUc3lI-K94Ks/preset:listing/plain/ebfda9cfd242452b6f7f2a534cf2fae3-2801774245248781625.jpg',
#   'webp_image': 'https://cdn.chotot.com/tJlH4Yz9vZzQTfYm_51RdEj20egebir6gh-J13isUdQ/preset:listing/plain/ebfda9cfd242452b6f7f2a534cf2fae3-2801774245248781625.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/FXxXpWjQ6Rqmyt8H_9hEnn5NsZlR00IfK6GyM8LIGQg/preset:view/plain/c6093c40264cf1165e036b2fe36fe368-2801774245554123947.jpg',
#    'https://cdn.chotot.com/mC58fx5WdLepM8p4IgGCk6a3xTQQgbfUN92S2XeRBkg/preset:view/plain/fb1110d153034a01efd7bfa445cac4ea-2801774245639843371.jpg',
#    'https://cdn.chotot.com/YhU7J8qMmmQowy6SQXlV96bR5tM7TqMjUIZTlWUrey0/preset:view/plain/8a2aefb1d3e5443bf61c6eb69fcf634c-2801774245836998650.jpg',
#    'https://cdn.chotot.com/_xLdM9fHYq8_0a6c-d8IH3qoHNA2iadM-xS66aM2CxM/preset:view/plain/e7c9ec223a6a265929c266c6a9d966e8-2801774245526401139.jpg',
#    'https://cdn.chotot.com/Tczj_sa4N0rc8i6IaqxODDtJr1KqHV13lIbQ-D_90_0/preset:view/plain/490286754879d6cf73fd76f6aba4c8dc-2801774245400742067.jpg'],
#   'special_display': True,
#   'number_of_images': 8,
#   'avatar': 'https://cdn.chotot.com/uac2/23677342',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 35,
#   'region_v2': 13000,
#   'area_v2': 13109,
#   'ward': 9290,
#   'ward_name': 'Phường 15',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.800452,106.70504',
#   'longitude': 106.70504,
#   'latitude': 10.800452,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': True,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '35 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'D1',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 13},
#  {'ad_id': 140018008,
#   'list_id': 101542650,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 4280667,
#   'projectid': 443,
#   'project_oid': '1000826750',
#   'account_oid': None,
#   'account_name': 'Sỹ Bừng',
#   'shop_alias': 'fEAflCOMBhtbZnM',
#   'subject': 'Chính chủ cho thuê 2pn full NT ở ngay CH Luxgarden',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 102,
#   'area_name': 'Quận 7',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 8000000,
#   'price_string': '8 triệu/tháng',
#   'image': 'https://cdn.chotot.com/oJtJfXoHn8qJnkRqMPwCo3p6JhL_QOsWmVd-XjOXADI/preset:listing/plain/23ea214c7bd8d1b8f2e0a95198cd4192-2801275928451894863.jpg',
#   'webp_image': 'https://cdn.chotot.com/l_WzbFORRtvBKKvTbebGwq9_W-Ur-jXvl1DQ2MxIxRo/preset:listing/plain/23ea214c7bd8d1b8f2e0a95198cd4192-2801275928451894863.webp',
#   'videos': [],
#   'number_of_images': 7,
#   'shop': {'alias': 'fEAflCOMBhtbZnM',
#    'status': 'accepted',
#    'name': '4280667_10000',
#    'address': '167, nguyễn phúc nguyên , phường 10, quận 3',
#    'profileImageUrl': 'https://cdn.chotot.com/LJB4CFpUPlo6e0TwlPKXSNa0zBUU3ibHeQz07w7G_6s/preset:shopava/plain/becf47a08ff2ea60d945ecac4541ec13-2666463419439617125.jpg',
#    'createdDate': '2017-06-07T09:59:58.000Z',
#    'modifiedDate': 1669987008,
#    'urls': [{'url': 'canhogiarequan8616'}],
#    'shopsCategoriesRelationships': [{'categoryId': 1000}]},
#   'avatar': 'https://cdn.chotot.com/uac2/4280667',
#   'rooms': 2,
#   'property_legal_document': 1,
#   'apartment_type': 1,
#   'size': 62,
#   'region_v2': 13000,
#   'area_v2': 13102,
#   'ward': 9472,
#   'ward_name': 'Phường Phú Thuận',
#   'toilets': 2,
#   'deposit': 16000000,
#   'contain_videos': 2,
#   'location': '10.74272,106.74063',
#   'longitude': 106.74063,
#   'latitude': 10.74272,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': '370',
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '62 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Nguyễn Văn Quỳ',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 14},
#  {'ad_id': 140095536,
#   'list_id': 101607109,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 16931467,
#   'account_oid': None,
#   'account_name': 'Thư Vinhomes',
#   'subject': 'CHO THUÊ CĂN HỘ VINHOMES GRAND PARK GIÁ TỪ 3.8TR',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 119,
#   'area_name': 'Thành phố Thủ Đức',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 3800000,
#   'price_string': '3,8 triệu/tháng',
#   'image': 'https://cdn.chotot.com/XibeivlkDhytW3jwprn2Lw5wlDVEy6eAEMgKdSjyhRc/preset:listing/plain/22e9813e8c45d20eb46a0917e3ff84c2-2801561829597300468.jpg',
#   'webp_image': 'https://cdn.chotot.com/2-wPsLy_cb2bxpOGCFF5SS2zW05MYbfh-_J-sKVu624/preset:listing/plain/22e9813e8c45d20eb46a0917e3ff84c2-2801561829597300468.webp',
#   'videos': [],
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/16931467',
#   'rooms': 1,
#   'apartment_type': 1,
#   'size': 30,
#   'region_v2': 13000,
#   'area_v2': 13119,
#   'ward': 9251,
#   'ward_name': 'Phường Long Thạnh Mỹ (Quận 9 cũ)',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.84718,106.83029',
#   'longitude': 106.83029,
#   'latitude': 10.84718,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '30 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Đường Nguyễn Xiển',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 15},
#  {'ad_id': 139860387,
#   'list_id': 101414843,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 24018373,
#   'account_oid': None,
#   'account_name': 'Nguyễn Minh Tuấn',
#   'subject': 'Đang Trống Studio FUll nội thất cao cấp -hifriendz',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 119,
#   'area_name': 'Thành phố Thủ Đức',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 6000000,
#   'price_string': '6 triệu/tháng',
#   'image': 'https://cdn.chotot.com/3GKJb_Cihbf5krzLwgS-eWGcFGhZhsvnmU-KXP5WcG4/preset:listing/plain/037963c36a6f3f20496a4422888f1752-2800627291041136570.jpg',
#   'webp_image': 'https://cdn.chotot.com/Z3WT2xjdAu8Xovd6VoLY-EtqL-EBn9msgYx0s6KFbrM/preset:listing/plain/037963c36a6f3f20496a4422888f1752-2800627291041136570.webp',
#   'videos': [],
#   'number_of_images': 8,
#   'avatar': 'https://cdn.chotot.com/uac2/24018373',
#   'rooms': 1,
#   'apartment_type': 1,
#   'size': 35,
#   'region_v2': 13000,
#   'area_v2': 13119,
#   'ward': 9341,
#   'ward_name': 'Phường An Phú (Quận 2 cũ)',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.79835,106.75246',
#   'longitude': 106.75246,
#   'latitude': 10.79835,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '35 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Mai Chí Thọ',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 16},
#  {'ad_id': 139784879,
#   'list_id': 101349684,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 21517567,
#   'projectid': 109,
#   'project_oid': '1782368488',
#   'account_oid': None,
#   'account_name': 'Jackie Tuấn',
#   'subject': 'CHO THUÊ 2PN VINHOME BASON 19 TRIỆU NHÀ ĐANG TRỐNG',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 96,
#   'area_name': 'Quận 1',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 19000000,
#   'price_string': '19 triệu/tháng',
#   'image': 'https://cdn.chotot.com/DMBqQTGeM8rC_aTRJXg728wCQnNoFhdV27pE9lPHHfo/preset:listing/plain/b256bd74b674d0e83c0bce1e18014cc1-2800682886702925436.jpg',
#   'webp_image': 'https://cdn.chotot.com/u17wEU5zQeiSqGgrdRpwn52kBKfAj4RjUUIyumZgKy8/preset:listing/plain/b256bd74b674d0e83c0bce1e18014cc1-2800682886702925436.webp',
#   'videos': [],
#   'number_of_images': 5,
#   'avatar': 'https://cdn.chotot.com/uac2/21517567',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 80,
#   'region_v2': 13000,
#   'area_v2': 13096,
#   'ward': 9219,
#   'ward_name': 'Phường Bến Nghé',
#   'toilets': 2,
#   'contain_videos': 2,
#   'location': '10.77779,106.70712',
#   'longitude': 106.70712,
#   'latitude': 10.77779,
#   'phone_hidden': True,
#   'address': 'Tôn Đức Thắng',
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '80 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'đường Tôn Đức Thắng',
#   'street_name': 'Tôn Đức Thắng',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 17},
#  {'ad_id': 136291333,
#   'list_id': 98472498,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 23396883,
#   'projectid': 383,
#   'project_oid': '1148357882',
#   'account_oid': None,
#   'account_name': 'Lê Đức',
#   'subject': 'Căn Hộ 2PN 75m2 The Sun Avenue Q2',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 119,
#   'area_name': 'Thành phố Thủ Đức',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 14000000,
#   'price_string': '14 triệu/tháng',
#   'image': 'https://cdn.chotot.com/8lYJDnJep18xBiQGznFz2WWksBWeww00cGbYFMsXSFI/preset:listing/plain/f3bc61f68d405c93d2e76917d821579d-2788094099908103669.jpg',
#   'webp_image': 'https://cdn.chotot.com/UPi4zbDyZ83kX8Hnj9tEpADg5fXgN6rFA6JEKtzje-c/preset:listing/plain/f3bc61f68d405c93d2e76917d821579d-2788094099908103669.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/Cu45iU8t-QuxFTLrMPPrM5GHl0z2SRH5UQgPjxEBzzY/preset:view/plain/7c36e5a3ad53a512afde8d43ffbe0f74-2788094100233503860.jpg',
#    'https://cdn.chotot.com/aJvQvuvlwiHI7R4uda6bg0okYDeXczxglYZpJuBDKSs/preset:view/plain/8fa8bd9b233a33b6129e19d881e507e4-2788094101027582942.jpg',
#    'https://cdn.chotot.com/HSjIDRNV0ZBAS587jv5T-VhoEqDI3UsfpBEsv96sHoY/preset:view/plain/3c0fe8c084d9e9101a1917150f4782ad-2788094101213077731.jpg',
#    'https://cdn.chotot.com/SYw3ZSom1RuYuSiHJuBl-e8M-2wn4ZSpahp43fEM-f0/preset:view/plain/9bc1ab20ca84aad7e736271b074c09c4-2788094101223621656.jpg',
#    'https://cdn.chotot.com/LmQyPnGaGa1Q350OQs4HTk9MEPX8uyOziTXadSLGY50/preset:view/plain/ec49fb35705607eb4b7f4aeb3da33087-2788094101166460405.jpg'],
#   'special_display': True,
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/23396883',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 75,
#   'region_v2': 13000,
#   'area_v2': 13119,
#   'ward': 9341,
#   'ward_name': 'Phường An Phú (Quận 2 cũ)',
#   'toilets': 2,
#   'contain_videos': 2,
#   'location': '10.79675,106.75218',
#   'longitude': 106.75218,
#   'latitude': 10.79675,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '75 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Đường Mai Chí Thọ, Phường An Phú, Quận 2, Hồ Chí Minh',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 18},
#  {'ad_id': 140161665,
#   'list_id': 101661814,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 913392,
#   'projectid': 2052,
#   'project_oid': '343957681',
#   'account_oid': None,
#   'account_name': 'Hậu Trần',
#   'subject': 'Cho Thuê Nhiều *Căn Hộ *SUNRISE CITY VIEW',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 102,
#   'area_name': 'Quận 7',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 10000000,
#   'price_string': '10 triệu/tháng',
#   'image': 'https://cdn.chotot.com/mT5_uqNAlov3ppQd40erorvOvkHhOQ7e8A_QMFx9338/preset:listing/plain/b61afb48eb79488fbda01263cca724fc-2801772597028783813.jpg',
#   'webp_image': 'https://cdn.chotot.com/uN6hRd21iRE1Ht_zDYEd4uvDnIzvknPXQb1_g46TR1g/preset:listing/plain/b61afb48eb79488fbda01263cca724fc-2801772597028783813.webp',
#   'videos': [],
#   'number_of_images': 4,
#   'avatar': 'https://cdn.chotot.com/uac2/913392',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 69,
#   'region_v2': 13000,
#   'area_v2': 13102,
#   'ward': 9469,
#   'ward_name': 'Phường Tân Hưng',
#   'toilets': 2,
#   'contain_videos': 2,
#   'location': '10.74367,106.70149',
#   'longitude': 106.70149,
#   'latitude': 10.74367,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '69 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Đường Nguyễn Hữu Thọ, Phường Tân Hưng, Quận 7, Hồ Chí Minh',
#   'street_name': 'Nguyễn Hữu Thọ',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 19},
#  {'ad_id': 140161874,
#   'list_id': 101661797,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 9043876,
#   'projectid': 12,
#   'project_oid': '864204857',
#   'account_oid': None,
#   'account_name': 'Lê Diễm Hương Huyền',
#   'subject': 'CĂN HỘ TRESOR - 2PN FULL NỘI THẤT',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 99,
#   'area_name': 'Quận 4',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 19000000,
#   'price_string': '19 triệu/tháng',
#   'image': 'https://cdn.chotot.com/lo4ZEIVLTcNMNcxaPN3thcyOy1L-NRukmnNUnNyZAiU/preset:listing/plain/d16e328cf940d2cdbc281e5d37f1ef55-2801774428490008724.jpg',
#   'webp_image': 'https://cdn.chotot.com/kqZ9_f0H1wlfIFHZUxCJVRXu1ghOunJ3EksME2Nzhuk/preset:listing/plain/d16e328cf940d2cdbc281e5d37f1ef55-2801774428490008724.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/d7TN7T-C9WZ8Kii5TLDwJJ5NtlWuQEpv2mDHdfD-BMU/preset:view/plain/27094c7bd3c7f50c2613c1a2a89482ca-2801774428476452227.jpg',
#    'https://cdn.chotot.com/0wVOmfKqb8cETndeMXW4GkU8C0i_rbcTxPsto7UhvVQ/preset:view/plain/cccd5580193aa0d4608e374c6a7ecc4e-2801774427048014200.jpg',
#    'https://cdn.chotot.com/hAj3P2DcFCq7R303Menl4nqUk5eKaC6Yj62DTw5zAGM/preset:view/plain/233b7aa24fcea39466c08f048eb3829d-2801774428507697528.jpg'],
#   'special_display': True,
#   'number_of_images': 4,
#   'avatar': 'https://cdn.chotot.com/uac2/9043876',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 65,
#   'region_v2': 13000,
#   'area_v2': 13099,
#   'ward': 9397,
#   'ward_name': 'Phường 13',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.76675,106.70295',
#   'longitude': 106.70295,
#   'latitude': 10.76675,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': '39',
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '65 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': '39 Đường Bến Vân Đồn',
#   'street_name': 'Bến Vân Đồn',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 20},
#  {'ad_id': 137787704,
#   'list_id': 99708659,
#   'list_time': None,
#   'date': '59 phút trước',
#   'account_id': 15981029,
#   'account_oid': None,
#   'account_name': 'Nguyễn Linh APARTMENT',
#   'subject': 'Căn hộ Quận 10_An Ninh Sạch Sẽ_Gần Toà VIETTEL',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 105,
#   'area_name': 'Quận 10',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 6300000,
#   'price_string': '6,3 triệu/tháng',
#   'image': 'https://cdn.chotot.com/9QprvKV7dDSDGjy6h53oM5XQZ4t2WCX-z-k690M9Nek/preset:listing/plain/e16dcb5dfedba23056ceeb10f379f422-2801285738674522264.jpg',
#   'webp_image': 'https://cdn.chotot.com/o9675yTI2c4JhgtktOuJhD81QKITpfKPykc55nDMsZM/preset:listing/plain/e16dcb5dfedba23056ceeb10f379f422-2801285738674522264.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/hDSV00sPxCVlv1BRKhwBaqYFBTTPhZdM4Hd7XoQjtAI/preset:view/plain/aef515c31a5b37fd5e0a7d2c161e6d40-2801285740932032784.jpg',
#    'https://cdn.chotot.com/iuxdJ39kjB_juKTKLzw2e0piAzly1XfhkviUPEuRtSw/preset:view/plain/fc1fb992308e7e0e14f568c0232784dd-2801285739199303355.jpg',
#    'https://cdn.chotot.com/ykguTMTAynaP9Ohzge5w2rGTOSIZtFxp1eSxpAprZcA/preset:view/plain/98f27f0c406f05daa1a50c9192684e72-2801285738710991722.jpg',
#    'https://cdn.chotot.com/RtX3ayBlV4XhQZ6LvGFC4Cs8h8HeIwGGmHTOlZhzZ8A/preset:view/plain/b17c2f8b3a09d7ee4d456b4f63e123a2-2801285742684407960.jpg',
#    'https://cdn.chotot.com/RZJk51iYjz7XNN_N5CGqOkdCKbvPuq7CyzKnmQxhjF0/preset:view/plain/8234e0d6fb6d7292b4f7c7bff4ceacf9-2801285742369883957.jpg'],
#   'special_display': True,
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/15981029',
#   'rooms': 1,
#   'property_legal_document': 1,
#   'apartment_type': 2,
#   'size': 30,
#   'region_v2': 13000,
#   'area_v2': 13105,
#   'ward': 9368,
#   'ward_name': 'Phường 12',
#   'block': 'A',
#   'floornumber': 3,
#   'toilets': 1,
#   'unitnumber': '1',
#   'unitnumber_display': 1,
#   'deposit': 6300,
#   'apartment_feature': 1,
#   'contain_videos': 2,
#   'location': '10.77493,106.66558',
#   'longitude': 106.66558,
#   'latitude': 10.77493,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': '491',
#   'protection_entitlement': True,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '30 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Đường Cách Mạng Tháng Tám',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 1},
#  {'ad_id': 130295918,
#   'list_id': 93547414,
#   'list_time': None,
#   'date': '59 phút trước',
#   'account_id': 2782360,
#   'projectid': 1,
#   'project_oid': '987630212',
#   'account_oid': None,
#   'account_name': 'PHAN ANH HÙNG',
#   'shop_alias': 'X5zJlLgXddb2RUm',
#   'subject': 'Cho thuê căn hộ city gate 3pn giá 9 triệu',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 103,
#   'area_name': 'Quận 8',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 9000000,
#   'price_string': '9 triệu/tháng',
#   'image': 'https://cdn.chotot.com/0dRt0C1LpgtVyAseJu4ctU_80YeSf3kXuHiCaq_XalQ/preset:listing/plain/3dd6a50217a33819277e4ce612748868-2766051298123399706.jpg',
#   'webp_image': 'https://cdn.chotot.com/XKmPCb5NOb_5Izy-doMVrp2oABwmCzc9OVhKo61l9NA/preset:listing/plain/3dd6a50217a33819277e4ce612748868-2766051298123399706.webp',
#   'videos': [],
#   'number_of_images': 7,
#   'shop': {'alias': 'X5zJlLgXddb2RUm',
#    'status': 'expired',
#    'name': 'PHAN ANH HÙNG BDS',
#    'address': 'phường 12, quận 10',
#    'profileImageUrl': 'https://cdn.chotot.com/JOpXCJx99rB9XDrADv8N-wIwpsAAkEGRdO2_nj-D4zk/preset:shopava/plain/f746a5656d07d626283c3d520f674f06-2769687142369395106.jpg',
#    'createdDate': '2022-04-25T03:14:05.000Z',
#    'modifiedDate': 1653448818,
#    'urls': [{'url': 'phan-anh-hung-bds'}],
#    'shopsCategoriesRelationships': [{'categoryId': 1000}]},
#   'avatar': 'https://cdn.chotot.com/uac2/2782360',
#   'rooms': 3,
#   'apartment_type': 1,
#   'size': 92,
#   'region_v2': 13000,
#   'area_v2': 13103,
#   'ward': 9454,
#   'ward_name': 'Phường 16',
#   'toilets': 2,
#   'deposit': 18000000,
#   'contain_videos': 2,
#   'location': '10.72873,106.62398',
#   'longitude': 106.62398,
#   'latitude': 10.72873,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': '15',
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '92 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '3 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Võ Văn Kiệt, phường 16, quận 8',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 2},
#  {'ad_id': 140162255,
#   'list_id': 101662114,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 21645975,
#   'account_oid': None,
#   'account_name': 'Mạnh Hùng AC Homes',
#   'subject': 'Căn Hộ Giá Rẻ Q.Tân Phú',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 113,
#   'area_name': 'Quận Tân Phú',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 3600000,
#   'price_string': '3,6 triệu/tháng',
#   'image': 'https://cdn.chotot.com/Hsd5sOBVK85nhSxjRdMHDK05-L8-YWw37pDLwK-99_Y/preset:listing/plain/d7ce18b72d6113d54b0fc913605026af-2801775966253165796.jpg',
#   'webp_image': 'https://cdn.chotot.com/H5yY8WM2qlCc8FUfCNPwMLdZJ2BKbxSnYqX65TkPFA4/preset:listing/plain/d7ce18b72d6113d54b0fc913605026af-2801775966253165796.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/Vqhvo_dXqPSYKvBmArR-_oHHTK4TPe40BW6wvcXcmw0/preset:view/plain/b569f74069a7948d6a8605a12d6fe5ca-2801775966002677445.jpg',
#    'https://cdn.chotot.com/3Jge3nqeHGtk0zNxe35yDYJ4tLaOSBtUAHjuXl8HHME/preset:view/plain/b8696a66f6105ec64197eae892f7f0b6-2801775966261637496.jpg',
#    'https://cdn.chotot.com/6cOoohblBIvSnbxbJgGivY5ffmsBrYVJILitLojEYOg/preset:view/plain/393f2f7eeaf15b8e485ae8d108eb6502-2801775965940919683.jpg'],
#   'special_display': True,
#   'number_of_images': 4,
#   'avatar': 'https://cdn.chotot.com/uac2/21645975',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 30,
#   'region_v2': 13000,
#   'area_v2': 13113,
#   'ward': 9315,
#   'ward_name': 'Phường Tây Thạnh',
#   'toilets': 1,
#   'deposit': 3600000,
#   'contain_videos': 2,
#   'location': '10.812291,106.62618',
#   'longitude': 106.62618,
#   'latitude': 10.812291,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '30 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Tây Thạnh',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 3},
#  {'ad_id': 140110416,
#   'list_id': 101631390,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 22301822,
#   'account_oid': None,
#   'account_name': 'Thế Anh',
#   'subject': 'STUDIO ra vào tự do BC THOÁNG cửa sổ LỚN ở liền❤❤',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 109,
#   'area_name': 'Quận Bình Thạnh',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 4100000,
#   'price_string': '4,1 triệu/tháng',
#   'image': 'https://cdn.chotot.com/nZ_QOxXASKq_9I7NiP7yTkHikJuMXLcCjHlcScURHnQ/preset:listing/plain/c7ef92d2dbf50ddcc1a0e7bc9625b353-2801593067958281693.jpg',
#   'webp_image': 'https://cdn.chotot.com/73VVd9uUyiYfu9frJ0GNZ4LWJAEFFsrhsMLYyU-eslE/preset:listing/plain/c7ef92d2dbf50ddcc1a0e7bc9625b353-2801593067958281693.webp',
#   'videos': [],
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/22301822',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 23,
#   'region_v2': 13000,
#   'area_v2': 13109,
#   'ward': 9287,
#   'ward_name': 'Phường 24',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.80713,106.70785',
#   'longitude': 106.70785,
#   'latitude': 10.80713,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': True,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '23 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Hẻm 47 Bùi Đình Túy',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 4},
#  {'ad_id': 139175708,
#   'list_id': 100844215,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 17194237,
#   'projectid': 122,
#   'project_oid': '1352502191',
#   'account_oid': None,
#   'account_name': 'Nguyễn thanh Huyền',
#   'subject': 'Cho thuê giá tốt  studio The Manor, view lung linh',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 109,
#   'area_name': 'Quận Bình Thạnh',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 12000000,
#   'price_string': '12 triệu/tháng',
#   'image': 'https://cdn.chotot.com/ecqpm92PIKqErrK747M20RFZNbYfrNVpTt7ZHEnfiRI/preset:listing/plain/73e0af0cbdf2ce587f9246eae57b6875-2798143367443377965.jpg',
#   'webp_image': 'https://cdn.chotot.com/z27ocPGEoCvD1n6aIZDr5euX0jkgHtIhjilrmBtZ_xk/preset:listing/plain/73e0af0cbdf2ce587f9246eae57b6875-2798143367443377965.webp',
#   'videos': [],
#   'number_of_images': 10,
#   'avatar': 'https://cdn.chotot.com/uac2/17194237',
#   'rooms': 1,
#   'apartment_type': 1,
#   'size': 38,
#   'region_v2': 13000,
#   'area_v2': 13109,
#   'ward': 9296,
#   'ward_name': 'Phường 22',
#   'direction': 5,
#   'floornumber': 20,
#   'toilets': 1,
#   'balconydirection': 6,
#   'contain_videos': 2,
#   'location': '10.78921,106.71094',
#   'longitude': 106.71094,
#   'latitude': 10.78921,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '38 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
# ...
#   'size': 50,
#   'region_v2': 13000,
#   'area_v2': 13109,
#   'ward': 9296,
#   'ward_name': 'Phường 22',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.79395,106.72092',
#   'longitude': 106.72092,
#   'latitude': 10.79395,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '50 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Nguyễn Hữu Cảnh',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 12},
#  {'ad_id': 140161831,
#   'list_id': 101661890,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 23677342,
#   'account_oid': None,
#   'account_name': 'THUỲ LING HOUSE',
#   'subject': '🆘1PN 35m2 MẶT TIỀN THOÁNG MÁT GIÁ ƯU ĐÃI BTHANH',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 109,
#   'area_name': 'Quận Bình Thạnh',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 7000000,
#   'price_string': '7 triệu/tháng',
#   'image': 'https://cdn.chotot.com/dNxtMpGmtl9uKEuXxGMSTkAJUHkvZYWhUc3lI-K94Ks/preset:listing/plain/ebfda9cfd242452b6f7f2a534cf2fae3-2801774245248781625.jpg',
#   'webp_image': 'https://cdn.chotot.com/tJlH4Yz9vZzQTfYm_51RdEj20egebir6gh-J13isUdQ/preset:listing/plain/ebfda9cfd242452b6f7f2a534cf2fae3-2801774245248781625.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/FXxXpWjQ6Rqmyt8H_9hEnn5NsZlR00IfK6GyM8LIGQg/preset:view/plain/c6093c40264cf1165e036b2fe36fe368-2801774245554123947.jpg',
#    'https://cdn.chotot.com/mC58fx5WdLepM8p4IgGCk6a3xTQQgbfUN92S2XeRBkg/preset:view/plain/fb1110d153034a01efd7bfa445cac4ea-2801774245639843371.jpg',
#    'https://cdn.chotot.com/YhU7J8qMmmQowy6SQXlV96bR5tM7TqMjUIZTlWUrey0/preset:view/plain/8a2aefb1d3e5443bf61c6eb69fcf634c-2801774245836998650.jpg',
#    'https://cdn.chotot.com/_xLdM9fHYq8_0a6c-d8IH3qoHNA2iadM-xS66aM2CxM/preset:view/plain/e7c9ec223a6a265929c266c6a9d966e8-2801774245526401139.jpg',
#    'https://cdn.chotot.com/Tczj_sa4N0rc8i6IaqxODDtJr1KqHV13lIbQ-D_90_0/preset:view/plain/490286754879d6cf73fd76f6aba4c8dc-2801774245400742067.jpg'],
#   'special_display': True,
#   'number_of_images': 8,
#   'avatar': 'https://cdn.chotot.com/uac2/23677342',
#   'rooms': 1,
#   'apartment_type': 2,
#   'size': 35,
#   'region_v2': 13000,
#   'area_v2': 13109,
#   'ward': 9290,
#   'ward_name': 'Phường 15',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.800452,106.70504',
#   'longitude': 106.70504,
#   'latitude': 10.800452,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': True,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '35 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'D1',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 13},
#  {'ad_id': 140018008,
#   'list_id': 101542650,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 4280667,
#   'projectid': 443,
#   'project_oid': '1000826750',
#   'account_oid': None,
#   'account_name': 'Sỹ Bừng',
#   'shop_alias': 'fEAflCOMBhtbZnM',
#   'subject': 'Chính chủ cho thuê 2pn full NT ở ngay CH Luxgarden',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 102,
#   'area_name': 'Quận 7',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 8000000,
#   'price_string': '8 triệu/tháng',
#   'image': 'https://cdn.chotot.com/oJtJfXoHn8qJnkRqMPwCo3p6JhL_QOsWmVd-XjOXADI/preset:listing/plain/23ea214c7bd8d1b8f2e0a95198cd4192-2801275928451894863.jpg',
#   'webp_image': 'https://cdn.chotot.com/l_WzbFORRtvBKKvTbebGwq9_W-Ur-jXvl1DQ2MxIxRo/preset:listing/plain/23ea214c7bd8d1b8f2e0a95198cd4192-2801275928451894863.webp',
#   'videos': [],
#   'number_of_images': 7,
#   'shop': {'alias': 'fEAflCOMBhtbZnM',
#    'status': 'accepted',
#    'name': '4280667_10000',
#    'address': '167, nguyễn phúc nguyên , phường 10, quận 3',
#    'profileImageUrl': 'https://cdn.chotot.com/LJB4CFpUPlo6e0TwlPKXSNa0zBUU3ibHeQz07w7G_6s/preset:shopava/plain/becf47a08ff2ea60d945ecac4541ec13-2666463419439617125.jpg',
#    'createdDate': '2017-06-07T09:59:58.000Z',
#    'modifiedDate': 1669987008,
#    'urls': [{'url': 'canhogiarequan8616'}],
#    'shopsCategoriesRelationships': [{'categoryId': 1000}]},
#   'avatar': 'https://cdn.chotot.com/uac2/4280667',
#   'rooms': 2,
#   'property_legal_document': 1,
#   'apartment_type': 1,
#   'size': 62,
#   'region_v2': 13000,
#   'area_v2': 13102,
#   'ward': 9472,
#   'ward_name': 'Phường Phú Thuận',
#   'toilets': 2,
#   'deposit': 16000000,
#   'contain_videos': 2,
#   'location': '10.74272,106.74063',
#   'longitude': 106.74063,
#   'latitude': 10.74272,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': '370',
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '62 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Nguyễn Văn Quỳ',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 14},
#  {'ad_id': 140095536,
#   'list_id': 101607109,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 16931467,
#   'account_oid': None,
#   'account_name': 'Thư Vinhomes',
#   'subject': 'CHO THUÊ CĂN HỘ VINHOMES GRAND PARK GIÁ TỪ 3.8TR',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 119,
#   'area_name': 'Thành phố Thủ Đức',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 3800000,
#   'price_string': '3,8 triệu/tháng',
#   'image': 'https://cdn.chotot.com/XibeivlkDhytW3jwprn2Lw5wlDVEy6eAEMgKdSjyhRc/preset:listing/plain/22e9813e8c45d20eb46a0917e3ff84c2-2801561829597300468.jpg',
#   'webp_image': 'https://cdn.chotot.com/2-wPsLy_cb2bxpOGCFF5SS2zW05MYbfh-_J-sKVu624/preset:listing/plain/22e9813e8c45d20eb46a0917e3ff84c2-2801561829597300468.webp',
#   'videos': [],
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/16931467',
#   'rooms': 1,
#   'apartment_type': 1,
#   'size': 30,
#   'region_v2': 13000,
#   'area_v2': 13119,
#   'ward': 9251,
#   'ward_name': 'Phường Long Thạnh Mỹ (Quận 9 cũ)',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.84718,106.83029',
#   'longitude': 106.83029,
#   'latitude': 10.84718,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '30 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Đường Nguyễn Xiển',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 15},
#  {'ad_id': 139860387,
#   'list_id': 101414843,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 24018373,
#   'account_oid': None,
#   'account_name': 'Nguyễn Minh Tuấn',
#   'subject': 'Đang Trống Studio FUll nội thất cao cấp -hifriendz',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 119,
#   'area_name': 'Thành phố Thủ Đức',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 6000000,
#   'price_string': '6 triệu/tháng',
#   'image': 'https://cdn.chotot.com/3GKJb_Cihbf5krzLwgS-eWGcFGhZhsvnmU-KXP5WcG4/preset:listing/plain/037963c36a6f3f20496a4422888f1752-2800627291041136570.jpg',
#   'webp_image': 'https://cdn.chotot.com/Z3WT2xjdAu8Xovd6VoLY-EtqL-EBn9msgYx0s6KFbrM/preset:listing/plain/037963c36a6f3f20496a4422888f1752-2800627291041136570.webp',
#   'videos': [],
#   'number_of_images': 8,
#   'avatar': 'https://cdn.chotot.com/uac2/24018373',
#   'rooms': 1,
#   'apartment_type': 1,
#   'size': 35,
#   'region_v2': 13000,
#   'area_v2': 13119,
#   'ward': 9341,
#   'ward_name': 'Phường An Phú (Quận 2 cũ)',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.79835,106.75246',
#   'longitude': 106.75246,
#   'latitude': 10.79835,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '35 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '1 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'street_name': 'Mai Chí Thọ',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 16},
#  {'ad_id': 139784879,
#   'list_id': 101349684,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 21517567,
#   'projectid': 109,
#   'project_oid': '1782368488',
#   'account_oid': None,
#   'account_name': 'Jackie Tuấn',
#   'subject': 'CHO THUÊ 2PN VINHOME BASON 19 TRIỆU NHÀ ĐANG TRỐNG',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 96,
#   'area_name': 'Quận 1',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 19000000,
#   'price_string': '19 triệu/tháng',
#   'image': 'https://cdn.chotot.com/DMBqQTGeM8rC_aTRJXg728wCQnNoFhdV27pE9lPHHfo/preset:listing/plain/b256bd74b674d0e83c0bce1e18014cc1-2800682886702925436.jpg',
#   'webp_image': 'https://cdn.chotot.com/u17wEU5zQeiSqGgrdRpwn52kBKfAj4RjUUIyumZgKy8/preset:listing/plain/b256bd74b674d0e83c0bce1e18014cc1-2800682886702925436.webp',
#   'videos': [],
#   'number_of_images': 5,
#   'avatar': 'https://cdn.chotot.com/uac2/21517567',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 80,
#   'region_v2': 13000,
#   'area_v2': 13096,
#   'ward': 9219,
#   'ward_name': 'Phường Bến Nghé',
#   'toilets': 2,
#   'contain_videos': 2,
#   'location': '10.77779,106.70712',
#   'longitude': 106.70712,
#   'latitude': 10.77779,
#   'phone_hidden': True,
#   'address': 'Tôn Đức Thắng',
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '80 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'đường Tôn Đức Thắng',
#   'street_name': 'Tôn Đức Thắng',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 17},
#  {'ad_id': 136291333,
#   'list_id': 98472498,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 23396883,
#   'projectid': 383,
#   'project_oid': '1148357882',
#   'account_oid': None,
#   'account_name': 'Lê Đức',
#   'subject': 'Căn Hộ 2PN 75m2 The Sun Avenue Q2',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 119,
#   'area_name': 'Thành phố Thủ Đức',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 14000000,
#   'price_string': '14 triệu/tháng',
#   'image': 'https://cdn.chotot.com/8lYJDnJep18xBiQGznFz2WWksBWeww00cGbYFMsXSFI/preset:listing/plain/f3bc61f68d405c93d2e76917d821579d-2788094099908103669.jpg',
#   'webp_image': 'https://cdn.chotot.com/UPi4zbDyZ83kX8Hnj9tEpADg5fXgN6rFA6JEKtzje-c/preset:listing/plain/f3bc61f68d405c93d2e76917d821579d-2788094099908103669.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/Cu45iU8t-QuxFTLrMPPrM5GHl0z2SRH5UQgPjxEBzzY/preset:view/plain/7c36e5a3ad53a512afde8d43ffbe0f74-2788094100233503860.jpg',
#    'https://cdn.chotot.com/aJvQvuvlwiHI7R4uda6bg0okYDeXczxglYZpJuBDKSs/preset:view/plain/8fa8bd9b233a33b6129e19d881e507e4-2788094101027582942.jpg',
#    'https://cdn.chotot.com/HSjIDRNV0ZBAS587jv5T-VhoEqDI3UsfpBEsv96sHoY/preset:view/plain/3c0fe8c084d9e9101a1917150f4782ad-2788094101213077731.jpg',
#    'https://cdn.chotot.com/SYw3ZSom1RuYuSiHJuBl-e8M-2wn4ZSpahp43fEM-f0/preset:view/plain/9bc1ab20ca84aad7e736271b074c09c4-2788094101223621656.jpg',
#    'https://cdn.chotot.com/LmQyPnGaGa1Q350OQs4HTk9MEPX8uyOziTXadSLGY50/preset:view/plain/ec49fb35705607eb4b7f4aeb3da33087-2788094101166460405.jpg'],
#   'special_display': True,
#   'number_of_images': 6,
#   'avatar': 'https://cdn.chotot.com/uac2/23396883',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 75,
#   'region_v2': 13000,
#   'area_v2': 13119,
#   'ward': 9341,
#   'ward_name': 'Phường An Phú (Quận 2 cũ)',
#   'toilets': 2,
#   'contain_videos': 2,
#   'location': '10.79675,106.75218',
#   'longitude': 106.75218,
#   'latitude': 10.79675,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '75 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Đường Mai Chí Thọ, Phường An Phú, Quận 2, Hồ Chí Minh',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 18},
#  {'ad_id': 140161665,
#   'list_id': 101661814,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 913392,
#   'projectid': 2052,
#   'project_oid': '343957681',
#   'account_oid': None,
#   'account_name': 'Hậu Trần',
#   'subject': 'Cho Thuê Nhiều *Căn Hộ *SUNRISE CITY VIEW',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 102,
#   'area_name': 'Quận 7',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 10000000,
#   'price_string': '10 triệu/tháng',
#   'image': 'https://cdn.chotot.com/mT5_uqNAlov3ppQd40erorvOvkHhOQ7e8A_QMFx9338/preset:listing/plain/b61afb48eb79488fbda01263cca724fc-2801772597028783813.jpg',
#   'webp_image': 'https://cdn.chotot.com/uN6hRd21iRE1Ht_zDYEd4uvDnIzvknPXQb1_g46TR1g/preset:listing/plain/b61afb48eb79488fbda01263cca724fc-2801772597028783813.webp',
#   'videos': [],
#   'number_of_images': 4,
#   'avatar': 'https://cdn.chotot.com/uac2/913392',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 69,
#   'region_v2': 13000,
#   'area_v2': 13102,
#   'ward': 9469,
#   'ward_name': 'Phường Tân Hưng',
#   'toilets': 2,
#   'contain_videos': 2,
#   'location': '10.74367,106.70149',
#   'longitude': 106.70149,
#   'latitude': 10.74367,
#   'phone_hidden': True,
#   'owner': False,
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '69 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': 'Đường Nguyễn Hữu Thọ, Phường Tân Hưng, Quận 7, Hồ Chí Minh',
#   'street_name': 'Nguyễn Hữu Thọ',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 19},
#  {'ad_id': 140161874,
#   'list_id': 101661797,
#   'list_time': None,
#   'date': '1 giờ trước',
#   'account_id': 9043876,
#   'projectid': 12,
#   'project_oid': '864204857',
#   'account_oid': None,
#   'account_name': 'Lê Diễm Hương Huyền',
#   'subject': 'CĂN HỘ TRESOR - 2PN FULL NỘI THẤT',
#   'body': None,
#   'category': 1010,
#   'category_name': None,
#   'area': 99,
#   'area_name': 'Quận 4',
#   'region': 13,
#   'region_name': 'Tp Hồ Chí Minh',
#   'company_ad': True,
#   'type': 'u',
#   'price': 19000000,
#   'price_string': '19 triệu/tháng',
#   'image': 'https://cdn.chotot.com/lo4ZEIVLTcNMNcxaPN3thcyOy1L-NRukmnNUnNyZAiU/preset:listing/plain/d16e328cf940d2cdbc281e5d37f1ef55-2801774428490008724.jpg',
#   'webp_image': 'https://cdn.chotot.com/kqZ9_f0H1wlfIFHZUxCJVRXu1ghOunJ3EksME2Nzhuk/preset:listing/plain/d16e328cf940d2cdbc281e5d37f1ef55-2801774428490008724.webp',
#   'videos': [],
#   'special_display_images': ['https://cdn.chotot.com/d7TN7T-C9WZ8Kii5TLDwJJ5NtlWuQEpv2mDHdfD-BMU/preset:view/plain/27094c7bd3c7f50c2613c1a2a89482ca-2801774428476452227.jpg',
#    'https://cdn.chotot.com/0wVOmfKqb8cETndeMXW4GkU8C0i_rbcTxPsto7UhvVQ/preset:view/plain/cccd5580193aa0d4608e374c6a7ecc4e-2801774427048014200.jpg',
#    'https://cdn.chotot.com/hAj3P2DcFCq7R303Menl4nqUk5eKaC6Yj62DTw5zAGM/preset:view/plain/233b7aa24fcea39466c08f048eb3829d-2801774428507697528.jpg'],
#   'special_display': True,
#   'number_of_images': 4,
#   'avatar': 'https://cdn.chotot.com/uac2/9043876',
#   'rooms': 2,
#   'apartment_type': 1,
#   'size': 65,
#   'region_v2': 13000,
#   'area_v2': 13099,
#   'ward': 9397,
#   'ward_name': 'Phường 13',
#   'toilets': 1,
#   'contain_videos': 2,
#   'location': '10.76675,106.70295',
#   'longitude': 106.70295,
#   'latitude': 10.76675,
#   'phone_hidden': True,
#   'owner': False,
#   'street_number': '39',
#   'protection_entitlement': False,
#   'escrow_can_deposit': 2,
#   'params': [{'id': 'size', 'value': '65 m²', 'label': 'Diện tích'},
#    {'id': 'rooms', 'value': '2 PN', 'label': 'Số phòng ngủ'}],
#   'zero_deposit': False,
#   'detail_address': '39 Đường Bến Vân Đồn',
#   'street_name': 'Bến Vân Đồn',
#   'pty_jupiter': '0',
#   'phone': None,
#   'adIndex': 20}]

# %% [markdown]
# ## 2.4. Filter data

# %%
need_keys = ['ad_id', 'list_id', 'subject', 'price', 'size', 'rooms', 'toilets', 'area_name', 'region_name', 'ward_name', 'street_name', 'detail_address', 'escrow_can_deposit', 'zero_deposit', 'longitude', 'latitude']

def filer_apartment(apartment):
    return { key: apartment[key] if key in apartment else '' for key in need_keys }

new_apartments = list(map(filer_apartment, apartments))
new_apartments[0]
# Out:
# {'ad_id': 134359927,
#  'list_id': 96900062,
#  'subject': '🍀CĂN HỘ 1 PHÒNG NGỦ NGAY ĐH NGÂN HÀNG.SPKT đường 7',
#  'price': 6000000,
#  'size': 35,
#  'rooms': 1,
#  'toilets': 1,
#  'area_name': 'Thành phố Thủ Đức',
#  'region_name': 'Tp Hồ Chí Minh',
#  'ward_name': 'Phường Linh Trung (Quận Thủ Đức cũ)',
#  'street_name': 'Đường Số 7',
#  'detail_address': '',
#  'escrow_can_deposit': 2,
#  'zero_deposit': False,
#  'longitude': 106.76977,
#  'latitude': 10.85836}

# %% [markdown]
# ### 2.5. Write to csv

# %%
list_apartment = [[apartment[key] for key in need_keys] for apartment in new_apartments]

with open('./data/hcm-apartment-rent-data.csv', 'w') as f:
    write = csv.writer(f)
    write.writerow(need_keys)
    write.writerows(list_apartment)
